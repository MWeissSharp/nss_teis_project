# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
teis_p = pd.read_csv('../data/teis_p.csv')
teis_p
# Out:
#       POE  Child ID         DOB County Name   County SES    Child Phase  \
# 0      ET    411812  12/14/2016      Blount  Transitional  Notification
# 1      ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2      ET    419400    3/4/2016       Roane  Transitional  Notification
# 3      ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4      ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...    ..       ...         ...         ...           ...           ...
# 96575  UC    519094   4/10/2020       Macon  Transitional   Eligibility
# 96576  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 96577  UC    525460   8/27/2019      Sumner   Competitive  Notification
# 96578  UC    528535    2/8/2022       Smith  Transitional    Evaluation
# 96579  UC    514216    2/4/2021      Sumner   Competitive          IFSP
#
#       Active Service Coordinator Notification Date Parent Consent Date  \
# ...

# %%
teis_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96580 entries, 0 to 96579
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   POE                        96580 non-null  object
#  1   Child ID                   96580 non-null  int64
#  2   DOB                        96580 non-null  object
#  3   County Name                96576 non-null  object
#  4   County SES                 96576 non-null  object
#  5   Child Phase                96580 non-null  object
#  6   Active                     96580 non-null  object
#  7   Service Coordinator        96579 non-null  object
#  8   Notification Date          96580 non-null  object
#  9   Parent Consent Date        70026 non-null  object
#  10  Referral Source Type Name  96580 non-null  object
#  11  Initial Eligibility        68221 non-null  object
#  12  Initial Eligibility Date   68221 non-null  object
# ...

# %%
teis_p = teis_p.rename(columns = {'County SES ' : 'County SES'})
teis_p
# Out:
#       POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0      ET    411812  12/14/2016      Blount  Transitional  Notification
# 1      ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2      ET    419400    3/4/2016       Roane  Transitional  Notification
# 3      ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4      ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...    ..       ...         ...         ...           ...           ...
# 96575  UC    519094   4/10/2020       Macon  Transitional   Eligibility
# 96576  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 96577  UC    525460   8/27/2019      Sumner   Competitive  Notification
# 96578  UC    528535    2/8/2022       Smith  Transitional    Evaluation
# 96579  UC    514216    2/4/2021      Sumner   Competitive          IFSP
#
#       Active Service Coordinator Notification Date Parent Consent Date  \
# ...

# %%
teis_c = pd.read_csv('../data/teis_c.csv')
teis_c
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification/ Referral Date  \
# ...

# %%
teis_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113256 entries, 0 to 113255
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          113256 non-null  object
#  1   Child ID                     113256 non-null  int64
#  2   DOB                          113256 non-null  object
#  3   County Name                  113251 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  113256 non-null  object
#  6   Active                       113256 non-null  object
#  7   Service Coordinator          113255 non-null  object
#  8   Notification/ Referral Date  113256 non-null  object
#  9   Parent Consent Date          58101 non-null   object
#  10  Referral Source Type Name    113256 non-null  object
#  11  Initial Eligibility          40762 non-null   object
# ...

# %%
teis_c = teis_c.rename(columns = {'Notification/ Referral Date' : 'Notification Date'})
teis_c
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification Date  \
# ...

# %%
teis_pc = pd.merge(teis_p, teis_c,how = 'outer')
teis_pc
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 191573  UC    528094   3/17/2022      Warren       At-Risk  Notification
# 191574  UC    529508   5/21/2022      Sumner   Competitive  Notification
# 191575  UC    528651  10/30/2021       White  Transitional    Evaluation
# 191576  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 191577  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
#
#        Active Service Coordinator Notification Date Parent Consent Date  ...  \
# ...

# %%
teis_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191578 entries, 0 to 191577
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          191578 non-null  object
#  1   Child ID                     191578 non-null  int64
#  2   DOB                          191578 non-null  object
#  3   County Name                  191570 non-null  object
#  4   County SES                   191570 non-null  object
#  5   Child Phase                  191578 non-null  object
#  6   Active                       191578 non-null  object
#  7   Service Coordinator          191577 non-null  object
#  8   Notification Date            191578 non-null  object
#  9   Parent Consent Date          127024 non-null  object
#  10  Referral Source Type Name    191578 non-null  object
#  11  Initial Eligibility          107265 non-null  object
# ...

# %%
teis_pc = teis_pc.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Child Count', 'Referral Source Category'])

# %%
teis_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191578 entries, 0 to 191577
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   POE                        191578 non-null  object
#  1   Child ID                   191578 non-null  int64
#  2   DOB                        191578 non-null  object
#  3   County Name                191570 non-null  object
#  4   County SES                 191570 non-null  object
#  5   Child Phase                191578 non-null  object
#  6   Active                     191578 non-null  object
#  7   Service Coordinator        191577 non-null  object
#  8   Notification Date          191578 non-null  object
#  9   Parent Consent Date        127024 non-null  object
#  10  Referral Source Type Name  191578 non-null  object
#  11  Initial Eligibility        107265 non-null  object
#  12  Initial Eligibility Date   107265 non-null  object
# ...

# %%
teis_pc
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 191573  UC    528094   3/17/2022      Warren       At-Risk  Notification
# 191574  UC    529508   5/21/2022      Sumner   Competitive  Notification
# 191575  UC    528651  10/30/2021       White  Transitional    Evaluation
# 191576  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 191577  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
#
#        Active Service Coordinator Notification Date Parent Consent Date  ...  \
# ...

# %%
teis_pc.value_counts('POE')
# Out:
# POE
# ET    33642
# GN    33534
# MD    28913
# SC    24940
# FT    19226
# UC    15363
# SE    14790
# NW    10730
# SW    10440
# dtype: int64

# %%
teis_pc.value_counts('County SES')
# Out:
# County SES
# Transitional    122397
# Competitive      37875
# At-Risk          22322
# Attainment        4634
# Distressed        4342
# dtype: int64

# %%
teis_pc.value_counts('County Name')
# Out:
# County Name
# Shelby        28899
# Davidson      18610
# Knox          14357
# Rutherford     9612
# Hamilton       7698
#               ...
# Perry           175
# Clay            163
# Van Buren       151
# Pickett          90
# Moore            86
# Length: 95, dtype: int64

# %%
teis_pc.value_counts('Service Coordinator')
# Out:
# Service Coordinator
# Signal Centers-EEA        12991
# Kim Correll               10896
# Rebecca Boshers-ES         5990
# Jasmine Douglass           5346
# Stacia Hall-Admin          4132
#                           ...
# RaeKenya Walker-DS            1
# Sandra Couch - DSS            1
# Brenda Rust-DS                1
# Stephanie Scott -Admin        1
# Jennifer Hodges-SC            1
# Length: 441, dtype: int64

# %%
teis_pc.value_counts('Referral Source Type Name')
# Out:
# Referral Source Type Name
# PCP                              72921
# DCS                              40005
# Parent                           39653
# Hospital                         11564
# Dept. of Health                   5901
# NICU                              4970
# Other                             4343
# Other Health Care Provider        3945
# Early Head Start/Head Start       1779
# Speech Therapist                  1145
# PT                                1093
# Family and Friends                 926
# Foster Parent                      762
# Child Care provider                743
# Community/Child Find Activity      676
# EIRA                               587
# NHS                                317
# OT                                 143
# PICU                                46
# LEA                                 27
# DHS                                 21
# TIPS                                 6
# CAPTA                                3
# ...

# %%
teis_pc.head(25)
# Out:
#    POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0   ET    411812 2016-12-14      Blount  Transitional  Notification      I
# 1   ET    417398 2015-04-06        Knox  Transitional   Eligibility      I
# 2   ET    419400 2016-03-04       Roane  Transitional  Notification      I
# 3   ET    397571 2015-05-11        Knox  Transitional   Eligibility      I
# 4   ET    404648 2015-09-23        Knox  Transitional          IFSP      I
# 5   ET    418289 2015-09-23        Knox  Transitional   Eligibility      I
# 6   ET    407988 2014-02-22        Knox  Transitional  Notification      I
# 7   ET    401498 2016-03-12        Knox  Transitional   Eligibility      I
# 8   ET    409028 2016-09-29      Sevier  Transitional          IFSP      I
# 9   ET    388306 2015-01-30      Sevier  Transitional   Eligibility      I
# 10  ET    418144 2017-03-22       Roane  Transitional  Notification      I
# ...

# %%
teis_pc['age'] = ''
teis_pc
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 191573  UC    528094   3/17/2022      Warren       At-Risk  Notification
# 191574  UC    529508   5/21/2022      Sumner   Competitive  Notification
# 191575  UC    528651  10/30/2021       White  Transitional    Evaluation
# 191576  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 191577  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
#
#        Active Service Coordinator Notification Date Parent Consent Date  ...  \
# ...

# %%
teis_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191578 entries, 0 to 191577
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   POE                        191578 non-null  object
#  1   Child ID                   191578 non-null  int64
#  2   DOB                        191578 non-null  object
#  3   County Name                191570 non-null  object
#  4   County SES                 191570 non-null  object
#  5   Child Phase                191578 non-null  object
#  6   Active                     191578 non-null  object
#  7   Service Coordinator        191577 non-null  object
#  8   Notification Date          191578 non-null  object
#  9   Parent Consent Date        127024 non-null  object
#  10  Referral Source Type Name  191578 non-null  object
#  11  Initial Eligibility        107265 non-null  object
#  12  Initial Eligibility Date   107265 non-null  object
# ...

# %%
teis_pc['age'] = teis_pc['DOB']
teis_pc.head()
# Out:
#   POE  Child ID         DOB County Name    County SES   Child Phase Active  \
# 0  ET    411812  12/14/2016      Blount  Transitional  Notification      I
# 1  ET    417398    4/6/2015        Knox  Transitional   Eligibility      I
# 2  ET    419400    3/4/2016       Roane  Transitional  Notification      I
# 3  ET    397571   5/11/2015        Knox  Transitional   Eligibility      I
# 4  ET    404648   9/23/2015        Knox  Transitional          IFSP      I
#
#   Service Coordinator Notification Date Parent Consent Date  ...  \
# 0      Charity Decker        12/16/2016                 NaN  ...
# 1     Jackie Campbell         4/24/2017            5/2/2017  ...
# 2      Kelly Brackney          6/6/2017                 NaN  ...
# 3        Wendy Burton         5/24/2017           6/13/2017  ...
# 4         Sarah Scott         7/18/2016           7/28/2016  ...
#
#   Referral Count Evaluation Count Eligibility Count IFSP Count Fiscal Year.1  \
# ...

# %%
teis_pc.DOB = pd.to_datetime(teis_pc.DOB)

# %%
datetime.date.today()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 datetime.date.today()
#
# NameError: name 'datetime' is not defined

# %%
teis_pc.age = teis_pc(now - teis_pc['DOB'])
teis_pc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 teis_pc.age = teis_pc(now - teis_pc['DOB'])
#       2 teis_pc.head()
#
# NameError: name 'now' is not defined

# %%
teis_pc
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    411812 2016-12-14      Blount  Transitional  Notification
# 1       ET    417398 2015-04-06        Knox  Transitional   Eligibility
# 2       ET    419400 2016-03-04       Roane  Transitional  Notification
# 3       ET    397571 2015-05-11        Knox  Transitional   Eligibility
# 4       ET    404648 2015-09-23        Knox  Transitional          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 191573  UC    528094 2022-03-17      Warren       At-Risk  Notification
# 191574  UC    529508 2022-05-21      Sumner   Competitive  Notification
# 191575  UC    528651 2021-10-30       White  Transitional    Evaluation
# 191576  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 191577  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
#
#        Active Service Coordinator Notification Date Parent Consent Date  ...  \
# ...

# %%
for index, row in teis_pc.iterrows():
    if row['Exit Date'] == str(teis_pc['Exit Date'],str.extract('%m/%d/%%yy')):
        teis_pc.loc[index, 'Exit Date'] = '%m/%d/%%yy'
    else:
       row['Exit Date'] == pd.to_datetime(teis_pc[index,'Exit Date'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       1 for index, row in teis_pc.iterrows():
# ----> 2     if row['Exit Date'] == str(teis_pc['Exit Date'],str.extract('%m/%d/%%yy')):
#       3         teis_pc.loc[index, 'Exit Date'] = '%m/%d/%%yy'
#       4     else:
#
# AttributeError: type object 'str' has no attribute 'extract'

# %%
teis_pc['Exit Date'] = pd.to_datetime(teis_pc['Exit Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: year 44560 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# ...
