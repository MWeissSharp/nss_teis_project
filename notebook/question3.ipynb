# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from datetime import date

# %%
teis_p = pd.read_csv('../data/teis_p.csv')
teis_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96580 entries, 0 to 96579
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   POE                        96580 non-null  object
#  1   Child ID                   96580 non-null  int64
#  2   DOB                        96580 non-null  object
#  3   County Name                96576 non-null  object
#  4   County SES                 96576 non-null  object
#  5   Child Phase                96580 non-null  object
#  6   Active                     96580 non-null  object
#  7   Service Coordinator        96579 non-null  object
#  8   Notification Date          96580 non-null  object
#  9   Parent Consent Date        70026 non-null  object
#  10  Referral Source Type Name  96580 non-null  object
#  11  Initial Eligibility        68221 non-null  object
#  12  Initial Eligibility Date   68221 non-null  object
#  13  Initial IFSP Date          45493 non-null  object
#  14  Latest IFSP Date           44331 non-null  object
#  15  Exit Reason                85194 non-null  object
#  16  Exit Date                  85194 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 12.5+ MB

# %%
teis_c = pd.read_csv('../data/teis_c.csv')
teis_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113256 entries, 0 to 113255
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          113256 non-null  object
#  1   Child ID                     113256 non-null  int64
#  2   DOB                          113256 non-null  object
#  3   County Name                  113251 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  113256 non-null  object
#  6   Active                       113256 non-null  object
#  7   Service Coordinator          113255 non-null  object
#  8   Notification/ Referral Date  113256 non-null  object
#  9   Parent Consent Date          58101 non-null   object
#  10  Referral Source Type Name    113256 non-null  object
#  11  Initial Eligibility          40762 non-null   object
#  12  Initial Eligibility Date     40762 non-null   object
#  13  Initial IFSP Date            8010 non-null    object
#  14  Latest IFSP Date             7983 non-null    object
#  15  Exit Reason                  39366 non-null   object
#  16  Exit Date                    39366 non-null   object
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  int64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  int64
#  25  Fiscal Year.1                113256 non-null  int64
#  26  Child Count                  113256 non-null  int64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  object
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  int64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     113256 non-null  object
# dtypes: float64(6), int64(6), object(22)
# memory usage: 29.4+ MB

# %%
teis_c = teis_c.rename(columns = {'Notification/ Referral Date' : 'Notification Date'})
teis_p = teis_p.rename(columns = {'County SES ' : 'County SES'})

# %%
teis_merge = pd.merge(teis_c, teis_p, how='outer')
teis_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191578 entries, 0 to 191577
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          191578 non-null  object
#  1   Child ID                     191578 non-null  int64
#  2   DOB                          191578 non-null  object
#  3   County Name                  191570 non-null  object
#  4   County SES                   191570 non-null  object
#  5   Child Phase                  191578 non-null  object
#  6   Active                       191578 non-null  object
#  7   Service Coordinator          191577 non-null  object
#  8   Notification Date            191578 non-null  object
#  9   Parent Consent Date          127024 non-null  object
#  10  Referral Source Type Name    191578 non-null  object
#  11  Initial Eligibility          107265 non-null  object
#  12  Initial Eligibility Date     107265 non-null  object
#  13  Initial IFSP Date            53185 non-null   object
#  14  Latest IFSP Date             51996 non-null   object
#  15  Exit Reason                  106768 non-null  object
#  16  Exit Date                    106768 non-null  object
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  float64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  float64
#  25  Fiscal Year.1                113256 non-null  float64
#  26  Child Count                  113256 non-null  float64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  object
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  float64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     113256 non-null  object
# dtypes: float64(11), int64(1), object(22)
# memory usage: 51.2+ MB

# %%
full_teis= pd.concat([teis_c, teis_p])

# %%
#full_teis.to_csv('../data/full_teis.csv')

# %%
#teis_confused = full_teis[full_teis.duplicated(['Child ID', 'Notification Date'], keep=False)]
#teis_confused.info()
#teis_confused.to_csv('../data/teis_confused.csv')

# %%
teis_clean = full_teis[~full_teis.duplicated(['POE', 'Child ID', 'DOB', 'County Name', 'County SES', 'Child Phase',
       'Active', 'Service Coordinator', 'Notification Date',
       'Parent Consent Date', 'Referral Source Type Name',
       'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date',
       'Latest IFSP Date', 'Exit Reason', 'Exit Date'])]
teis_clean.info()
#pulling out rows that are the same across all columns that the two dataframes share
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191578 entries, 0 to 96579
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          191578 non-null  object
#  1   Child ID                     191578 non-null  int64
#  2   DOB                          191578 non-null  object
#  3   County Name                  191570 non-null  object
#  4   County SES                   191570 non-null  object
#  5   Child Phase                  191578 non-null  object
#  6   Active                       191578 non-null  object
#  7   Service Coordinator          191577 non-null  object
#  8   Notification Date            191578 non-null  object
#  9   Parent Consent Date          127024 non-null  object
#  10  Referral Source Type Name    191578 non-null  object
#  11  Initial Eligibility          107265 non-null  object
#  12  Initial Eligibility Date     107265 non-null  object
#  13  Initial IFSP Date            53185 non-null   object
#  14  Latest IFSP Date             51996 non-null   object
#  15  Exit Reason                  106768 non-null  object
#  16  Exit Date                    106768 non-null  object
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  float64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  float64
#  25  Fiscal Year.1                113256 non-null  float64
#  26  Child Count                  113256 non-null  float64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  object
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  float64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     113256 non-null  object
# dtypes: float64(11), int64(1), object(22)
# memory usage: 51.2+ MB

# %%
import re
from tqdm.notebook import tqdm

# %%
for ind, row in tqdm(teis_clean.iterrows()):
    if re.search('\d{5}', str(row['Exit Date'])):
        teis_clean.loc[ind, 'Exit Date'] = np.NaN
#this is clearing out the weird data that's in the 'Exit Date' column
# Out:
# 0it [00:00, ?it/s]

# %%
teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
teis_clean
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/1059363929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
#       POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0      ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1      FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
# 2      FT    403623 2016-02-05    Sullivan  Transitional   Eligibility      A
# 3      FT    404157 2015-12-06    Sullivan  Transitional          IFSP      A
# 4      FT    404154 2015-04-18     Hawkins       At-Risk          IFSP      A
# ...    ..       ...        ...         ...           ...           ...    ...
# 96572  UC    523485 2019-10-23      Sumner   Competitive          IFSP      A
# 96573  UC    528430 2022-01-05  Cumberland  Transitional          IFSP      A
# 96574  UC    515685 2019-08-14      Sumner   Competitive          IFSP      A
# 96577  UC    525460 2019-08-27      Sumner   Competitive  Notification      I
# 96579  UC    514216 2021-02-04      Sumner   Competitive          IFSP      I
#
#                 Service Coordinator Notification Date Parent Consent Date  \
# 0                      Kristi Borer        2016-07-01          2016-07-01
# 1      Jennifer Terranera - 45 days        2016-07-01                 NaT
# 2                       Amy Talbert        2016-07-01          2016-07-20
# 3                    Candice Cradic        2016-07-01          2016-07-22
# 4                    Kathy Jeffries        2016-07-01          2016-07-18
# ...                             ...               ...                 ...
# 96572               Miriam Espinosa        2022-03-02          2022-03-10
# 96573                    Lisa Davis        2022-05-10          2022-05-18
# 96574                 Cindy Willard        2021-12-01          2021-12-07
# 96577             Sherry Roberts-DS        2022-03-29                 NaT
# 96579                     Dawn Reed        2021-11-05          2021-11-10
#
#        ... Service Coordinator Counter Fiscal Year.1 Child Count  \
# 0      ...                         1.0        2016.0         1.0
# 1      ...                         1.0        2016.0         1.0
# 2      ...                         1.0        2016.0         1.0
# 3      ...                         1.0        2016.0         1.0
# 4      ...                         1.0        2016.0         1.0
# ...    ...                         ...           ...         ...
# 96572  ...                         NaN           NaN         NaN
# 96573  ...                         NaN           NaN         NaN
# 96574  ...                         NaN           NaN         NaN
# 96577  ...                         NaN           NaN         NaN
# 96579  ...                         NaN           NaN         NaN
#
#       2012 Child Count 2013 Child Count  third DOB Late Referral  Qtr   QTR   \
# 0                  NaN              NaN 2017-08-09           NaN  1.0  Qtr 1
# 1                  NaN              NaN 2016-07-31           1.0  1.0  Qtr 1
# 2                  NaN              NaN 2019-02-05           NaN  1.0  Qtr 1
# 3                  NaN              NaN 2018-12-06           NaN  1.0  Qtr 1
# 4                  NaN              NaN 2018-04-18           NaN  1.0  Qtr 1
# ...                ...              ...        ...           ...  ...    ...
# 96572              NaN              NaN        NaT           NaN  NaN    NaN
# 96573              NaN              NaN        NaT           NaN  NaN    NaN
# 96574              NaN              NaN        NaT           NaN  NaN    NaN
# 96577              NaN              NaN        NaT           NaN  NaN    NaN
# 96579              NaN              NaN        NaT           NaN  NaN    NaN
#
#       Referral Source Category
# 0                        #REF!
# 1                        #REF!
# 2                        #REF!
# 3                        #REF!
# 4                        #REF!
# ...                        ...
# 96572                      NaN
# 96573                      NaN
# 96574                      NaN
# 96577                      NaN
# 96579                      NaN
#
# [191578 rows x 34 columns]

# %%
teis_clean = teis_clean.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count',
                                        'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                       'Referral Source Category'])
teis_clean.head(2)
#there isn't meaningful data in these columns (at least not for the purposes of this project)
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1  FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
#
#             Service Coordinator Notification Date Parent Consent Date  ...  \
# 0                  Kristi Borer        2016-07-01          2016-07-01  ...
# 1  Jennifer Terranera - 45 days        2016-07-01                 NaT  ...
#
#   Latest IFSP Date                 Exit Reason  Exit Date Fiscal Year  \
# 0              NaN                         NaN        NaT   2016-2017
# 1              NaN  Referral less than 45 days 2016-07-01   2016-2017
#
#   Notification Month Tenn Region Fiscal Year.1  third DOB Late Referral  Qtr
# 0                Jul     Eastern        2016.0 2017-08-09           NaN  1.0
# 1                Jul     Eastern        2016.0 2016-07-31           1.0  1.0
#
# [2 rows x 24 columns]

# %%
all_teis_dups = teis_clean[teis_clean.duplicated(['Child ID', 'Notification Date'], keep=False)].sort_values('Child ID')
all_teis_dups
#pulling all rows that have 'Child ID' and 'Notification Date' in common to take a look
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 437     NW    351755 2013-11-13     Madison  Transitional    Evaluation
# 8367    NW    351755 2013-11-13     Madison  Transitional   Eligibility
# 13240   UC    353805 2013-12-04      Putnam  Transitional          IFSP
# 1552    UC    353805 2013-12-04      Putnam  Transitional    Evaluation
# 4142    MD    353900 2013-10-09      Shelby  Transitional  Notification
# ...     ..       ...        ...         ...           ...           ...
# 95952   UC    529587 2022-03-15      Sumner   Competitive   Eligibility
# 93343   SE    529597 2020-04-10      McMinn  Transitional   Eligibility
# 112947  SE    529597 2020-04-10      McMinn  Transitional  Notification
# 81090   FT    529609 2020-05-13  Washington  Transitional  Notification
# 111777  FT    529609 2020-05-13  Washington  Transitional  Notification
#
#        Active    Service Coordinator Notification Date Parent Consent Date  \
# 437         A              Rene Bard        2016-07-12          2016-07-12
# 8367        I              Rene Bard        2016-07-12          2016-07-12
# 13240       I             Anna Bolin        2016-08-05          2016-08-15
# 1552        A             Anna Bolin        2016-08-05          2016-08-15
# 4142        I        JoAnn Hinkle-DA        2016-09-29                 NaT
# ...       ...                    ...               ...                 ...
# 95952       I      Sherry Roberts-DS        2022-05-31          2022-06-08
# 93343       I     Jennifer Rose - ES        2022-05-31          2022-06-04
# 112947      A     Signal Centers-EEA        2022-05-31                 NaT
# 81090       I  Alicia Taylor - Admin        2022-05-31                 NaT
# 111777      A     Signal Centers-EEA        2022-05-31                 NaT
#
#         ... Latest IFSP Date                              Exit Reason  \
# 437     ...              NaN                                      NaN
# 8367    ...              NaN                    Ineligible for Part C
# 13240   ...              NaN  618 - Part B eligibility not determined
# 1552    ...              NaN                                      NaN
# 4142    ...              NaN               Referral less than 45 days
# ...     ...              ...                                      ...
# 95952   ...              NaN                    Ineligible for Part C
# 93343   ...              NaN                    Ineligible for Part C
# 112947  ...              NaN                                      NaN
# 81090   ...              NaN                        Unable to contact
# 111777  ...              NaN                                      NaN
#
#         Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 437           NaT   2016-2017                Jul     Western        2016.0
# 8367   2016-08-25         NaN                NaN         NaN           NaN
# 13240  2016-12-03         NaN                NaN         NaN           NaN
# 1552          NaT   2016-2017                Aug      Middle        2016.0
# 4142   2016-09-29   2016-2017                Sep     Western        2016.0
# ...           ...         ...                ...         ...           ...
# 95952  2022-06-24         NaN                NaN         NaN           NaN
# 93343  2022-06-27         NaN                NaN         NaN           NaN
# 112947        NaT   2021-2022                May     Eastern        2021.0
# 81090  2022-07-01         NaN                NaN         NaN           NaN
# 111777        NaT   2021-2022                May     Eastern        2021.0
#
#         third DOB Late Referral  Qtr
# 437    2016-11-13           NaN  1.0
# 8367          NaT           NaN  NaN
# 13240         NaT           NaN  NaN
# 1552   2016-12-04           NaN  1.0
# 4142   2016-10-09           1.0  1.0
# ...           ...           ...  ...
# 95952         NaT           NaN  NaN
# 93343         NaT           NaN  NaN
# 112947 2023-04-10           NaN  4.0
# 81090         NaT           NaN  NaN
# 111777 2023-05-13           NaN  4.0
#
# [152108 rows x 24 columns]

# %%
num_all_dup = len(np.unique(np.array(all_teis_dups['Child ID'])))
num_all_dup
# Out:
# 76054

# %%
county_dups = all_teis_dups[~all_teis_dups.duplicated(['County Name', 'Child ID', 'Notification Date'], keep=False)]
county_dups
#These are instances when the same referral was noted under 2 different counties
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 9221    SC    360673 2014-02-19  Rutherford   Competitive         IFSP      I
# 3088    GN    360673 2014-02-19    Davidson   Competitive  Eligibility      A
# 3729    ET    365886 2014-02-28      Blount  Transitional         IFSP      A
# 285     ET    365886 2014-02-28        Knox  Transitional         IFSP      I
# 66      FT    381125 2014-09-26  Washington  Transitional  Eligibility      A
# ...     ..       ...        ...         ...           ...          ...    ...
# 81300   FT    528738 2021-09-22      Unicoi       At-Risk         IFSP      A
# 111795  FT    528739 2021-09-22  Washington  Transitional  Eligibility      A
# 81287   FT    528739 2021-09-22      Unicoi       At-Risk         IFSP      A
# 92411   SE    529465 2020-11-11     Bradley  Transitional  Eligibility      A
# 112856  SE    529465 2020-11-11    Hamilton  Transitional   Evaluation      A
#
#        Service Coordinator Notification Date Parent Consent Date  ...  \
# 9221           LaKika King        2016-09-08          2016-09-16  ...
# 3088        Dalmys Sanchez        2016-09-08          2016-09-16  ...
# 3729           Karen Stock        2016-09-21                 NaT  ...
# 285            Karen Stock        2016-09-21          2016-09-22  ...
# 66          Melinda Sutton        2016-07-05          2016-07-25  ...
# ...                    ...               ...                 ...  ...
# 81300       Sarah McKinney        2022-05-16          2022-05-25  ...
# 111795     Melinda Burrell        2022-05-16          2022-05-25  ...
# 81287       Sarah McKinney        2022-05-16          2022-05-25  ...
# 92411     Jennifer Steward        2022-05-27          2022-05-31  ...
# 112856  Signal Centers-EEA        2022-05-27          2022-05-31  ...
#
#        Latest IFSP Date                              Exit Reason  Exit Date  \
# 9221           2/6/2017                    618 - Part B eligible 2017-02-18
# 3088                NaN                                      NaN        NaT
# 3729          9/26/2016                                      NaN        NaT
# 285            2/3/2017  618 - Part B eligibility not determined 2017-02-27
# 66                  NaN                                      NaN        NaT
# ...                 ...                                      ...        ...
# 81300         6/27/2022                                      NaN        NaT
# 111795              NaN                                      NaN        NaT
# 81287         6/27/2022                                      NaN        NaT
# 92411               NaN                                      NaN        NaT
# 112856              NaN                                      NaN        NaT
#
#        Fiscal Year Notification Month Tenn Region Fiscal Year.1  third DOB  \
# 9221           NaN                NaN         NaN           NaN        NaT
# 3088     2016-2017                Sep      Middle        2016.0 2017-02-19
# 3729     2016-2017                Sep     Eastern        2016.0 2017-02-28
# 285            NaN                NaN         NaN           NaN        NaT
# 66       2016-2017                Jul     Eastern        2016.0 2017-09-26
# ...            ...                ...         ...           ...        ...
# 81300          NaN                NaN         NaN           NaN        NaT
# 111795   2021-2022                May     Eastern        2021.0 2024-09-22
# 81287          NaN                NaN         NaN           NaN        NaT
# 92411          NaN                NaN         NaN           NaN        NaT
# 112856   2021-2022                May     Eastern        2021.0 2023-11-11
#
#        Late Referral  Qtr
# 9221             NaN  NaN
# 3088             NaN  1.0
# 3729             NaN  1.0
# 285              NaN  NaN
# 66               NaN  1.0
# ...              ...  ...
# 81300            NaN  NaN
# 111795           NaN  4.0
# 81287            NaN  NaN
# 92411            NaN  NaN
# 112856           NaN  4.0
#
# [6336 rows x 24 columns]

# %%
num_county_dup = len(np.unique(np.array(county_dups['Child ID'])))
num_county_dup
# Out:
# 3168

# %%
POE_dups = all_teis_dups[~all_teis_dups.duplicated(['POE', 'Child ID', 'Notification Date'], keep=False)]
POE_dups
#These are instances when the same referral was noted under 2 different POEs
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 9221    SC    360673 2014-02-19  Rutherford   Competitive         IFSP      I
# 3088    GN    360673 2014-02-19    Davidson   Competitive  Eligibility      A
# 769     ET    382571 2014-11-05      Sevier  Transitional         IFSP      I
# 3810    FT    382571 2014-11-05       Cocke    Distressed  Eligibility      A
# 2435    SW    385467 2015-01-31     Fayette  Transitional  Eligibility      A
# ...     ..       ...        ...         ...           ...          ...    ...
# 81455   FT    526514 2021-01-07     Hamblen  Transitional         IFSP      A
# 95224   UC    527542 2020-10-07      Sumner   Competitive         IFSP      A
# 110110  GN    527542 2020-10-07   Robertson  Transitional  Eligibility      A
# 111939  GN    529308 2020-06-01    Marshall  Transitional   Evaluation      A
# 90147   SC    529308 2020-06-01    Marshall  Transitional  Eligibility      A
#
#        Service Coordinator Notification Date Parent Consent Date  ...  \
# 9221           LaKika King        2016-09-08          2016-09-16  ...
# 3088        Dalmys Sanchez        2016-09-08          2016-09-16  ...
# 769          Tonia Hodsden        2016-09-22          2016-09-22  ...
# 3810        Barbara Bowman        2016-09-22          2016-09-22  ...
# 2435     Yalunda Whiteside        2016-08-24          2016-09-01  ...
# ...                    ...               ...                 ...  ...
# 81455         Averi Parker        2022-04-11          2022-04-27  ...
# 95224           Taylor Lee        2022-04-26          2022-05-03  ...
# 110110       Taylor Watson        2022-04-26          2022-05-03  ...
# 111939         Kim Correll        2022-05-25          2022-06-07  ...
# 90147          Kaye Curtis        2022-05-25          2022-06-07  ...
#
#        Latest IFSP Date            Exit Reason  Exit Date Fiscal Year  \
# 9221           2/6/2017  618 - Part B eligible 2017-02-18         NaN
# 3088                NaN                    NaN        NaT   2016-2017
# 769           4/11/2017  618 - Parent withdraw 2017-09-21         NaN
# 3810                NaN                    NaN        NaT   2016-2017
# 2435                NaN                    NaN        NaT   2016-2017
# ...                 ...                    ...        ...         ...
# 81455         5/18/2022                    NaN        NaT         NaN
# 95224         5/11/2022                    NaN        NaT         NaN
# 110110              NaN                    NaN        NaT   2021-2022
# 111939              NaN                    NaN        NaT   2021-2022
# 90147               NaN                    NaN        NaT         NaN
#
#        Notification Month Tenn Region Fiscal Year.1  third DOB Late Referral  \
# 9221                  NaN         NaN           NaN        NaT           NaN
# 3088                  Sep      Middle        2016.0 2017-02-19           NaN
# 769                   NaN         NaN           NaN        NaT           NaN
# 3810                  Sep     Eastern        2016.0 2017-11-05           NaN
# 2435                  Aug     Western        2016.0 2018-01-31           NaN
# ...                   ...         ...           ...        ...           ...
# 81455                 NaN         NaN           NaN        NaT           NaN
# 95224                 NaN         NaN           NaN        NaT           NaN
# 110110                Apr      Middle        2021.0 2023-10-07           NaN
# 111939                May      Middle        2021.0 2023-06-01           NaN
# 90147                 NaN         NaN           NaN        NaT           NaN
#
#         Qtr
# 9221    NaN
# 3088    1.0
# 769     NaN
# 3810    1.0
# 2435    1.0
# ...     ...
# 81455   NaN
# 95224   NaN
# 110110  4.0
# 111939  4.0
# 90147   NaN
#
# [2480 rows x 24 columns]

# %%
num_POE_dup = len(np.unique(np.array(POE_dups['Child ID'])))
num_POE_dup
# Out:
# 1240

# %%
county_status_dups = county_dups[county_dups.duplicated(['Child ID', 'Child Phase', 'Notification Date'], keep=False)]
county_status_dups
#looking at the duplicates that have different counties but the same status
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 3729    ET    365886 2014-02-28      Blount  Transitional         IFSP      A
# 285     ET    365886 2014-02-28        Knox  Transitional         IFSP      I
# 12365   UC    385283 2015-01-31      Putnam  Transitional         IFSP      I
# 13302   UC    385283 2015-01-31     Overton  Transitional         IFSP      A
# 12971   UC    386507 2014-10-24      Sumner   Competitive         IFSP      I
# ...     ..       ...        ...         ...           ...          ...    ...
# 107545  ET    523720 2021-01-05        Knox  Transitional         IFSP      A
# 80374   ET    524519 2021-12-28      Monroe       At-Risk  Eligibility      I
# 109200  SE    524519 2021-12-28     Bradley  Transitional  Eligibility      A
# 109557  ET    526317 2021-03-21      Sevier  Transitional  Eligibility      A
# 80646   FT    526317 2021-03-21      Greene       At-Risk  Eligibility      I
#
#        Service Coordinator Notification Date Parent Consent Date  ...  \
# 3729           Karen Stock        2016-09-21                 NaT  ...
# 285            Karen Stock        2016-09-21          2016-09-22  ...
# 12365           Kim Pierce        2017-04-25          2017-05-02  ...
# 13302           Kim Pierce        2017-04-25          2017-05-02  ...
# 12971      Miriam Espinosa        2016-11-01          2016-11-30  ...
# ...                    ...               ...                 ...  ...
# 107545      Kristi Hopwood        2022-03-07          2022-03-08  ...
# 80374      Leslie Milligan        2022-03-15          2022-03-21  ...
# 109200      Jaci Robertson        2022-03-15          2022-03-21  ...
# 109557      Cynthia Miller        2022-04-07          2022-04-13  ...
# 80646   Susan St. Lawrence        2022-04-07          2022-04-13  ...
#
#        Latest IFSP Date                              Exit Reason  Exit Date  \
# 3729          9/26/2016                                      NaN        NaT
# 285            2/3/2017  618 - Part B eligibility not determined 2017-02-27
# 12365        10/30/2017  618 - Part B eligibility not determined 2018-01-30
# 13302          5/2/2017                                      NaN        NaT
# 12971         6/15/2017                    618 - Parent withdraw 2017-09-13
# ...                 ...                                      ...        ...
# 107545         4/6/2022                                      NaN        NaT
# 80374               NaN                        Unable to contact 2022-05-31
# 109200              NaN                                      NaN        NaT
# 109557              NaN                                      NaN        NaT
# 80646               NaN                           Parent decline 2022-06-03
#
#        Fiscal Year Notification Month Tenn Region Fiscal Year.1  third DOB  \
# 3729     2016-2017                Sep     Eastern        2016.0 2017-02-28
# 285            NaN                NaN         NaN           NaN        NaT
# 12365          NaN                NaN         NaN           NaN        NaT
# 13302    2016-2017                Apr      Middle        2016.0 2018-01-31
# 12971          NaN                NaN         NaN           NaN        NaT
# ...            ...                ...         ...           ...        ...
# 107545   2021-2022                Mar     Eastern        2021.0 2024-01-05
# 80374          NaN                NaN         NaN           NaN        NaT
# 109200   2021-2022                Mar     Eastern        2021.0 2024-12-28
# 109557   2021-2022                Apr     Eastern        2021.0 2024-03-21
# 80646          NaN                NaN         NaN           NaN        NaT
#
#        Late Referral  Qtr
# 3729             NaN  1.0
# 285              NaN  NaN
# 12365            NaN  NaN
# 13302            NaN  4.0
# 12971            NaN  NaN
# ...              ...  ...
# 107545           NaN  3.0
# 80374            NaN  NaN
# 109200           NaN  3.0
# 109557           NaN  4.0
# 80646            NaN  NaN
#
# [978 rows x 24 columns]

# %%
teis_c[teis_c.duplicated(['Child ID', 'Notification Date'], keep=False)]
#reconfirming that this original dataframe doesn't have any rows that have the same Child ID and Notification Date
# Out:
# Empty DataFrame
# Columns: [POE, Child ID, DOB, County Name, County SES, Child Phase, Active, Service Coordinator, Notification Date, Parent Consent Date, Referral Source Type Name, Initial Eligibility, Initial Eligibility Date, Initial IFSP Date, Latest IFSP Date, Exit Reason, Exit Date, Fiscal Year, Notification Month, Tenn Region, Referral Count, Evaluation Count, Eligibility Count, IFSP Count, Service Coordinator Counter, Fiscal Year.1, Child Count, 2012 Child Count, 2013 Child Count, third DOB, Late Referral, Qtr,  QTR , Referral Source Category]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# #### Notes on our decisions regarding how to most effectively merge our data
# After exploring the duplicate data, we decided to drop all columns from the teis_c dataframe that it shares with the teis_p dataframe except for Child ID and Notification Date. This will allow us to merge without creating any duplicates, keep the "extra" columns in teis_c, and per the folks at TEIS, the data from the teis_p dataframe should supercede any from the teis_c dataframe because it is more current

# %%
teis_c2 = teis_c.drop(columns = ['POE', 'DOB', 'County Name', 'County SES', 'Child Phase', 'Active', 'Service Coordinator', 
                                 'Parent Consent Date', 'Referral Source Type Name', 'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP Date', 'Exit Reason', 'Exit Date',
                                 '2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count', 
                                 'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                 'Referral Source Category'])
teis_c2
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0         403339          7/1/2016   2016-2017                Jul     Eastern
# 1         404085          7/1/2016   2016-2017                Jul     Eastern
# 2         403623          7/1/2016   2016-2017                Jul     Eastern
# 3         404157          7/1/2016   2016-2017                Jul     Eastern
# 4         404154          7/1/2016   2016-2017                Jul     Eastern
# ...          ...               ...         ...                ...         ...
# 113251    528759         5/16/2022   2021-2022                May      Middle
# 113252    528534         5/11/2022   2021-2022                May      Middle
# 113253    528430         5/10/2022   2021-2022                May      Middle
# 113254    528253          5/6/2022   2021-2022                May      Middle
# 113255    528535         5/11/2022   2021-2022                May      Middle
#
#         Fiscal Year.1  third DOB  Late Referral  Qtr
# 0                2016   8/9/2017            NaN    1
# 1                2016  7/31/2016            1.0    1
# 2                2016   2/5/2019            NaN    1
# 3                2016  12/6/2018            NaN    1
# 4                2016  4/18/2018            NaN    1
# ...               ...        ...            ...  ...
# 113251           2021   4/7/2024            NaN    4
# 113252           2021  3/13/2025            NaN    4
# 113253           2021   1/5/2025            NaN    4
# 113254           2021  9/12/2023            NaN    4
# 113255           2021   2/8/2025            NaN    4
#
# [113256 rows x 9 columns]

# %%
teis_merge3 = pd.merge(teis_c2, teis_p, how='outer').sort_values(['Child ID'])
teis_merge3
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 25415     104085         1/20/2018   2017-2018                Jan      Middle
# 2092      350065         8/17/2016   2016-2017                Aug      Middle
# 437       351755         7/12/2016   2016-2017                Jul     Western
# 3369      353800         9/14/2016   2016-2017                Sep     Eastern
# 1552      353805          8/5/2016   2016-2017                Aug      Middle
# ...          ...               ...         ...                ...         ...
# 114109    531592          7/1/2022         NaN                NaN         NaN
# 114352    531593          7/1/2022         NaN                NaN         NaN
# 114075    531594          7/1/2022         NaN                NaN         NaN
# 114046    531595          7/1/2022         NaN                NaN         NaN
# 114959    531596          7/1/2022         NaN                NaN         NaN
#
#         Fiscal Year.1   third DOB  Late Referral  Qtr POE  ... Active  \
# 25415          2017.0    7/7/2010            1.0  3.0  GN  ...      I
# 2092           2016.0  10/15/2016            1.0  1.0  UC  ...      I
# 437            2016.0  11/13/2016            NaN  1.0  NW  ...      I
# 3369           2016.0   10/1/2016            1.0  1.0  FT  ...      I
# 1552           2016.0   12/4/2016            NaN  1.0  UC  ...      I
# ...               ...         ...            ...  ...  ..  ...    ...
# 114109            NaN         NaN            NaN  NaN  GN  ...      A
# 114352            NaN         NaN            NaN  NaN  GN  ...      A
# 114075            NaN         NaN            NaN  NaN  GN  ...      A
# 114046            NaN         NaN            NaN  NaN  GN  ...      A
# 114959            NaN         NaN            NaN  NaN  SC  ...      A
#
#                  Service Coordinator Parent Consent Date  \
# 25415                            NaN                 NaN
# 2092                 Steven Scarlett                 NaN
# 437                        Rene Bard           7/12/2016
# 3369    Jennifer Terranera - 45 days                 NaN
# 1552                      Anna Bolin           8/15/2016
# ...                              ...                 ...
# 114109                   Kim Correll                 NaN
# 114352                   Kim Correll                 NaN
# 114075                   Kim Correll                 NaN
# 114046                   Kim Correll                 NaN
# 114959                   Kim Correll                 NaN
#
#          Referral Source Type Name Initial Eligibility  \
# 25415                          DCS                 NaN
# 2092                           PCP                 NaN
# 437                         Parent          Ineligible
# 3369                        Parent                 NaN
# 1552               Dept. of Health            Eligible
# ...                            ...                 ...
# 114109                         PCP                 NaN
# 114352                         PCP                 NaN
# 114075  Other Health Care Provider                 NaN
# 114046                    Hospital                 NaN
# 114959                         PCP                 NaN
#
#        Initial Eligibility Date Initial IFSP Date Latest IFSP Date  \
# 25415                       NaN               NaN              NaN
# 2092                        NaN               NaN              NaN
# 437                   8/25/2016               NaN              NaN
# 3369                        NaN               NaN              NaN
# 1552                  10/5/2016        10/10/2016              NaN
# ...                         ...               ...              ...
# 114109                      NaN               NaN              NaN
# 114352                      NaN               NaN              NaN
# 114075                      NaN               NaN              NaN
# 114046                      NaN               NaN              NaN
# 114959                      NaN               NaN              NaN
#
#                                     Exit Reason  Exit Date
# 25415                         Unable to contact  1/25/2010
# 2092                          Unable to contact  8/31/2016
# 437                       Ineligible for Part C  8/25/2016
# 3369                 Referral less than 45 days  9/15/2016
# 1552    618 - Part B eligibility not determined  12/3/2016
# ...                                         ...        ...
# 114109                                      NaN        NaN
# 114352                                      NaN        NaN
# 114075                                      NaN        NaN
# 114046                                      NaN        NaN
# 114959                                      NaN        NaN
#
# [115524 rows x 24 columns]

# %%
teis_merge3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_merge3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
teis_merge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 25415 to 114959
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  datetime64[ns]
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third DOB                  113256 non-null  datetime64[ns]
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        96580 non-null   object
#  10  DOB                        96580 non-null   datetime64[ns]
#  11  County Name                96576 non-null   object
#  12  County SES                 96576 non-null   object
#  13  Child Phase                96580 non-null   object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        96579 non-null   object
#  16  Parent Consent Date        70026 non-null   datetime64[ns]
#  17  Referral Source Type Name  96580 non-null   object
#  18  Initial Eligibility        68221 non-null   object
#  19  Initial Eligibility Date   68221 non-null   object
#  20  Initial IFSP Date          45493 non-null   object
#  21  Latest IFSP Date           44331 non-null   object
#  22  Exit Reason                85194 non-null   object
#  23  Exit Date                  85194 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(3), int64(1), object(15)
# memory usage: 22.0+ MB

# %%
teis_c3 = teis_c.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count', 
                                 'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                 'Referral Source Category'])
teis_c3
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification Date  \
# 0           A                  Kristi Borer          7/1/2016
# 1           I  Jennifer Terranera - 45 days          7/1/2016
# 2           A                   Amy Talbert          7/1/2016
# 3           A                Candice Cradic          7/1/2016
# 4           A                Kathy Jeffries          7/1/2016
# ...       ...                           ...               ...
# 113251      A             Sherry Roberts-DS         5/16/2022
# 113252      A                   Robyn Hogan         5/11/2022
# 113253      A                    Lisa Davis         5/10/2022
# 113254      A                    Taylor Lee          5/6/2022
# 113255      A             Sherry Roberts-DS         5/11/2022
#
#        Parent Consent Date  ... Latest IFSP Date                 Exit Reason  \
# 0                   7/1/16  ...              NaN                         NaN
# 1                      NaN  ...              NaN  Referral less than 45 days
# 2                  7/20/16  ...              NaN                         NaN
# 3                  7/22/16  ...        8/10/2016                         NaN
# 4                  7/18/16  ...        7/28/2016                         NaN
# ...                    ...  ...              ...                         ...
# 113251           5/26/2022  ...              NaN                         NaN
# 113252           5/23/2022  ...        6/14/2022                         NaN
# 113253           5/18/2022  ...              NaN                         NaN
# 113254           5/11/2022  ...        5/31/2022                         NaN
# 113255           5/27/2022  ...              NaN                         NaN
#
#        Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 0            NaN   2016-2017                Jul     Eastern          2016
# 1       7/1/2016   2016-2017                Jul     Eastern          2016
# 2            NaN   2016-2017                Jul     Eastern          2016
# 3            NaN   2016-2017                Jul     Eastern          2016
# 4            NaN   2016-2017                Jul     Eastern          2016
# ...          ...         ...                ...         ...           ...
# 113251       NaN   2021-2022                May      Middle          2021
# 113252       NaN   2021-2022                May      Middle          2021
# 113253       NaN   2021-2022                May      Middle          2021
# 113254       NaN   2021-2022                May      Middle          2021
# 113255       NaN   2021-2022                May      Middle          2021
#
#         third DOB Late Referral Qtr
# 0        8/9/2017           NaN   1
# 1       7/31/2016           1.0   1
# 2        2/5/2019           NaN   1
# 3       12/6/2018           NaN   1
# 4       4/18/2018           NaN   1
# ...           ...           ...  ..
# 113251   4/7/2024           NaN   4
# 113252  3/13/2025           NaN   4
# 113253   1/5/2025           NaN   4
# 113254  9/12/2023           NaN   4
# 113255   2/8/2025           NaN   4
#
# [113256 rows x 24 columns]

# %%
for ind, row in tqdm(teis_c3.iterrows()):
    if re.search('\d{5}', str(row['Exit Date'])):
        teis_c3.loc[ind, 'Exit Date'] = np.NaN
# Out:
# 0it [00:00, ?it/s]

# %%
teis_c3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_c3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
teis_c3
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification Date  \
# 0           A                  Kristi Borer        2016-07-01
# 1           I  Jennifer Terranera - 45 days        2016-07-01
# 2           A                   Amy Talbert        2016-07-01
# 3           A                Candice Cradic        2016-07-01
# 4           A                Kathy Jeffries        2016-07-01
# ...       ...                           ...               ...
# 113251      A             Sherry Roberts-DS        2022-05-16
# 113252      A                   Robyn Hogan        2022-05-11
# 113253      A                    Lisa Davis        2022-05-10
# 113254      A                    Taylor Lee        2022-05-06
# 113255      A             Sherry Roberts-DS        2022-05-11
#
#        Parent Consent Date  ... Latest IFSP Date                 Exit Reason  \
# 0               2016-07-01  ...              NaN                         NaN
# 1                      NaT  ...              NaN  Referral less than 45 days
# 2               2016-07-20  ...              NaN                         NaN
# 3               2016-07-22  ...        8/10/2016                         NaN
# 4               2016-07-18  ...        7/28/2016                         NaN
# ...                    ...  ...              ...                         ...
# 113251          2022-05-26  ...              NaN                         NaN
# 113252          2022-05-23  ...        6/14/2022                         NaN
# 113253          2022-05-18  ...              NaN                         NaN
# 113254          2022-05-11  ...        5/31/2022                         NaN
# 113255          2022-05-27  ...              NaN                         NaN
#
#         Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 0             NaT   2016-2017                Jul     Eastern          2016
# 1      2016-07-01   2016-2017                Jul     Eastern          2016
# 2             NaT   2016-2017                Jul     Eastern          2016
# 3             NaT   2016-2017                Jul     Eastern          2016
# 4             NaT   2016-2017                Jul     Eastern          2016
# ...           ...         ...                ...         ...           ...
# 113251        NaT   2021-2022                May      Middle          2021
# 113252        NaT   2021-2022                May      Middle          2021
# 113253        NaT   2021-2022                May      Middle          2021
# 113254        NaT   2021-2022                May      Middle          2021
# 113255        NaT   2021-2022                May      Middle          2021
#
#         third DOB Late Referral Qtr
# 0      2017-08-09           NaN   1
# 1      2016-07-31           1.0   1
# 2      2019-02-05           NaN   1
# 3      2018-12-06           NaN   1
# 4      2018-04-18           NaN   1
# ...           ...           ...  ..
# 113251 2024-04-07           NaN   4
# 113252 2025-03-13           NaN   4
# 113253 2025-01-05           NaN   4
# 113254 2023-09-12           NaN   4
# 113255 2025-02-08           NaN   4
#
# [113256 rows x 24 columns]

# %%
teis_merge2 = pd.merge(teis_merge3, teis_c3, on=['Child ID', 'Notification Date'], how='left')
teis_merge2.info()
##Need to do this to bring back in the data for the rows in our merge that were present only in teis_c
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Child ID                     115524 non-null  int64
#  1   Notification Date            115524 non-null  datetime64[ns]
#  2   Fiscal Year_x                113256 non-null  object
#  3   Notification Month_x         113256 non-null  object
#  4   Tenn Region_x                113256 non-null  object
#  5   Fiscal Year.1_x              113256 non-null  float64
#  6   third DOB_x                  113256 non-null  datetime64[ns]
#  7   Late Referral_x              2829 non-null    float64
#  8   Qtr_x                        113256 non-null  float64
#  9   POE_x                        96580 non-null   object
#  10  DOB_x                        96580 non-null   datetime64[ns]
#  11  County Name_x                96576 non-null   object
#  12  County SES_x                 96576 non-null   object
#  13  Child Phase_x                96580 non-null   object
#  14  Active_x                     96580 non-null   object
#  15  Service Coordinator_x        96579 non-null   object
#  16  Parent Consent Date_x        70026 non-null   datetime64[ns]
#  17  Referral Source Type Name_x  96580 non-null   object
#  18  Initial Eligibility_x        68221 non-null   object
#  19  Initial Eligibility Date_x   68221 non-null   object
#  20  Initial IFSP Date_x          45493 non-null   object
#  21  Latest IFSP Date_x           44331 non-null   object
#  22  Exit Reason_x                85194 non-null   object
#  23  Exit Date_x                  85194 non-null   datetime64[ns]
#  24  POE_y                        113256 non-null  object
#  25  DOB_y                        113256 non-null  datetime64[ns]
#  26  County Name_y                113251 non-null  object
#  27  County SES_y                 113251 non-null  object
#  28  Child Phase_y                113256 non-null  object
#  29  Active_y                     113256 non-null  object
#  30  Service Coordinator_y        113255 non-null  object
#  31  Parent Consent Date_y        58101 non-null   datetime64[ns]
#  32  Referral Source Type Name_y  113256 non-null  object
#  33  Initial Eligibility_y        40762 non-null   object
#  34  Initial Eligibility Date_y   40762 non-null   object
#  35  Initial IFSP Date_y          8010 non-null    object
#  36  Latest IFSP Date_y           7983 non-null    object
#  37  Exit Reason_y                39366 non-null   object
#  38  Exit Date_y                  39121 non-null   datetime64[ns]
#  39  Fiscal Year_y                113256 non-null  object
#  40  Notification Month_y         113256 non-null  object
#  41  Tenn Region_y                113256 non-null  object
#  42  Fiscal Year.1_y              113256 non-null  float64
#  43  third DOB_y                  113256 non-null  datetime64[ns]
#  44  Late Referral_y              2829 non-null    float64
#  45  Qtr_y                        113256 non-null  float64
# dtypes: datetime64[ns](9), float64(6), int64(1), object(30)
# memory usage: 41.4+ MB

# %%
teis_merge2['Referral Source Type Name_x'] = teis_merge2['Referral Source Type Name_x'].fillna(teis_merge2['Referral Source Type Name_y'])
teis_merge2['Late Referral_x'] = teis_merge2['Late Referral_x'].fillna(teis_merge2['Late Referral_y'])
teis_merge2['Qtr_x'] = teis_merge2['Qtr_x'].fillna(teis_merge2['Qtr_y'])
teis_merge2['POE_x'] = teis_merge2['POE_x'].fillna(teis_merge2['POE_y'])
teis_merge2['DOB_x'] = teis_merge2['DOB_x'].fillna(teis_merge2['DOB_y'])
teis_merge2['County Name_x'] = teis_merge2['County Name_x'].fillna(teis_merge2['County Name_y'])
teis_merge2['County SES_x'] = teis_merge2['County SES_x'].fillna(teis_merge2['County SES_y'])
teis_merge2['Child Phase_x'] = teis_merge2['Child Phase_x'].fillna(teis_merge2['Child Phase_y'])
teis_merge2['Service Coordinator_x'] = teis_merge2['Service Coordinator_x'].fillna(teis_merge2['Service Coordinator_y'])
teis_merge2['Parent Consent Date_x'] = teis_merge2['Parent Consent Date_x'].fillna(teis_merge2['Parent Consent Date_y'])
teis_merge2['Initial Eligibility_x'] = teis_merge2['Initial Eligibility_x'].fillna(teis_merge2['Initial Eligibility_y'])
teis_merge2['Initial Eligibility Date_x'] = teis_merge2['Initial Eligibility Date_x'].fillna(teis_merge2['Initial Eligibility Date_y'])
teis_merge2['Initial IFSP Date_x'] = teis_merge2['Initial IFSP Date_x'].fillna(teis_merge2['Initial IFSP Date_y'])
teis_merge2['Latest IFSP Date_x'] = teis_merge2['Latest IFSP Date_x'].fillna(teis_merge2['Latest IFSP Date_y'])
teis_merge2['Exit Reason_x'] = teis_merge2['Exit Reason_x'].fillna(teis_merge2['Exit Reason_y'])
teis_merge2['Exit Date_x'] = teis_merge2['Exit Date_x'].fillna(teis_merge2['Exit Date_x'])
teis_merge2.info()
#pulling data from the teis_c3 dataframe into the columns that originated from the teis_merge3 dataframe but had null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Child ID                     115524 non-null  int64
#  1   Notification Date            115524 non-null  datetime64[ns]
#  2   Fiscal Year_x                113256 non-null  object
#  3   Notification Month_x         113256 non-null  object
#  4   Tenn Region_x                113256 non-null  object
#  5   Fiscal Year.1_x              113256 non-null  float64
#  6   third DOB_x                  113256 non-null  datetime64[ns]
#  7   Late Referral_x              2829 non-null    float64
#  8   Qtr_x                        113256 non-null  float64
#  9   POE_x                        115524 non-null  object
#  10  DOB_x                        115524 non-null  datetime64[ns]
#  11  County Name_x                115520 non-null  object
#  12  County SES_x                 115520 non-null  object
#  13  Child Phase_x                115524 non-null  object
#  14  Active_x                     96580 non-null   object
#  15  Service Coordinator_x        115523 non-null  object
#  16  Parent Consent Date_x        75365 non-null   datetime64[ns]
#  17  Referral Source Type Name_x  115524 non-null  object
#  18  Initial Eligibility_x        71884 non-null   object
#  19  Initial Eligibility Date_x   71884 non-null   object
#  20  Initial IFSP Date_x          45520 non-null   object
#  21  Latest IFSP Date_x           44539 non-null   object
#  22  Exit Reason_x                96177 non-null   object
#  23  Exit Date_x                  85194 non-null   datetime64[ns]
#  24  POE_y                        113256 non-null  object
#  25  DOB_y                        113256 non-null  datetime64[ns]
#  26  County Name_y                113251 non-null  object
#  27  County SES_y                 113251 non-null  object
#  28  Child Phase_y                113256 non-null  object
#  29  Active_y                     113256 non-null  object
#  30  Service Coordinator_y        113255 non-null  object
#  31  Parent Consent Date_y        58101 non-null   datetime64[ns]
#  32  Referral Source Type Name_y  113256 non-null  object
#  33  Initial Eligibility_y        40762 non-null   object
#  34  Initial Eligibility Date_y   40762 non-null   object
#  35  Initial IFSP Date_y          8010 non-null    object
#  36  Latest IFSP Date_y           7983 non-null    object
#  37  Exit Reason_y                39366 non-null   object
#  38  Exit Date_y                  39121 non-null   datetime64[ns]
#  39  Fiscal Year_y                113256 non-null  object
#  40  Notification Month_y         113256 non-null  object
#  41  Tenn Region_y                113256 non-null  object
#  42  Fiscal Year.1_y              113256 non-null  float64
#  43  third DOB_y                  113256 non-null  datetime64[ns]
#  44  Late Referral_y              2829 non-null    float64
#  45  Qtr_y                        113256 non-null  float64
# dtypes: datetime64[ns](9), float64(6), int64(1), object(30)
# memory usage: 41.4+ MB

# %%
teis_merge2 = teis_merge2.drop(columns = ['POE_y', 'DOB_y', 'County Name_y', 'County SES_y', 'Child Phase_y', 'Active_y',
                                          'Service Coordinator_y', 'Parent Consent Date_y', 'Referral Source Type Name_y', 
                                          'Initial Eligibility_y', 'Initial Eligibility Date_y', 'Initial IFSP Date_y',
                                          'Latest IFSP Date_y', 'Exit Reason_y', 'Exit Date_y', 'Fiscal Year_y',
                                          'Notification Month_y', 'Tenn Region_y', 'Fiscal Year.1_y', 'third DOB_y', 
                                          'Late Referral_y', 'Qtr_y'])
teis_merge2.info()
#dropping the no longer needed columns now that we have the cells needed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Child ID                     115524 non-null  int64
#  1   Notification Date            115524 non-null  datetime64[ns]
#  2   Fiscal Year_x                113256 non-null  object
#  3   Notification Month_x         113256 non-null  object
#  4   Tenn Region_x                113256 non-null  object
#  5   Fiscal Year.1_x              113256 non-null  float64
#  6   third DOB_x                  113256 non-null  datetime64[ns]
#  7   Late Referral_x              2829 non-null    float64
#  8   Qtr_x                        113256 non-null  float64
#  9   POE_x                        115524 non-null  object
#  10  DOB_x                        115524 non-null  datetime64[ns]
#  11  County Name_x                115520 non-null  object
#  12  County SES_x                 115520 non-null  object
#  13  Child Phase_x                115524 non-null  object
#  14  Active_x                     96580 non-null   object
#  15  Service Coordinator_x        115523 non-null  object
#  16  Parent Consent Date_x        75365 non-null   datetime64[ns]
#  17  Referral Source Type Name_x  115524 non-null  object
#  18  Initial Eligibility_x        71884 non-null   object
#  19  Initial Eligibility Date_x   71884 non-null   object
#  20  Initial IFSP Date_x          45520 non-null   object
#  21  Latest IFSP Date_x           44539 non-null   object
#  22  Exit Reason_x                96177 non-null   object
#  23  Exit Date_x                  85194 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(3), int64(1), object(15)
# memory usage: 22.0+ MB

# %%
teis_merge2 = teis_merge2.rename(columns= {'Fiscal Year_x': 'Fiscal Year',
                                           'Notification Month_x' : 'Notification Month', 
                                           'Tenn Region_x' : 'Tenn Region', 
                                           'Fiscal Year.1_x' : 'Fiscal Year.1',
                                           'third DOB_x' : 'third_DOB',
                                           'Late Referral_x' : 'Late Referral',
                                           'Qtr_x' : 'Qtr',
                                           'POE_x' : 'POE',
                                           'DOB_x' : 'DOB',
                                           'County Name_x' : 'County Name',
                                           'County SES_x' : 'County SES',
                                           'Child Phase_x' : 'Child Phase',
                                           'Active_x' : 'Active',
                                           'Service Coordinator_x' : 'Service Coordinator',
                                           'Parent Consent Date_x' : 'Parent Consent',
                                           'Referral Source Type Name_x' : 'Referral Source Type Name',
                                           'Initial Eligibility_x' : 'Initial Eligibility',
                                           'Initial Eligibility Date_x' : 'Initial Eligibility Date',
                                           'Initial IFSP Date_x' : 'Initial IFSP Date',
                                           'Latest IFSP Date_x' : 'Latest IFSP',
                                           'Exit Reason_x' : 'Exit Reason',
                                           'Exit Date_x' : 'Exit Date'})
teis_merge2.info()
#renaming columns to get rid of the '_x'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  datetime64[ns]
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third_DOB                  113256 non-null  datetime64[ns]
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        115524 non-null  object
#  10  DOB                        115524 non-null  datetime64[ns]
#  11  County Name                115520 non-null  object
#  12  County SES                 115520 non-null  object
#  13  Child Phase                115524 non-null  object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        115523 non-null  object
#  16  Parent Consent             75365 non-null   datetime64[ns]
#  17  Referral Source Type Name  115524 non-null  object
#  18  Initial Eligibility        71884 non-null   object
#  19  Initial Eligibility Date   71884 non-null   object
#  20  Initial IFSP Date          45520 non-null   object
#  21  Latest IFSP                44539 non-null   object
#  22  Exit Reason                96177 non-null   object
#  23  Exit Date                  85194 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(3), int64(1), object(15)
# memory usage: 22.0+ MB

# %%
teis_merge2['Year'] = teis_merge2['Notification Date'].dt.year
teis_merge2.head(2)
# Out:
#    Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0    104085        2018-01-20   2017-2018                Jan      Middle
# 1    350065        2016-08-17   2016-2017                Aug      Middle
#
#    Fiscal Year.1  third_DOB  Late Referral  Qtr POE  ... Service Coordinator  \
# 0         2017.0 2010-07-07            1.0  3.0  GN  ...                 NaN
# 1         2016.0 2016-10-15            1.0  1.0  UC  ...     Steven Scarlett
#
#   Parent Consent Referral Source Type Name Initial Eligibility  \
# 0            NaT                       DCS                 NaN
# 1            NaT                       PCP                 NaN
#
#   Initial Eligibility Date Initial IFSP Date Latest IFSP        Exit Reason  \
# 0                      NaN               NaN         NaN  Unable to contact
# 1                      NaN               NaN         NaN  Unable to contact
#
#    Exit Date  Year
# 0 2010-01-25  2018
# 1 2016-08-31  2016
#
# [2 rows x 25 columns]

# %%
all_dups2 = teis_merge2[teis_merge2.duplicated(['Child ID', 'Notification Date'], keep=False)].sort_values('Child ID')
all_dups2
#making sure that there aren't any unanticipated duplicates
# Out:
# Empty DataFrame
# Columns: [Child ID, Notification Date, Fiscal Year, Notification Month, Tenn Region, Fiscal Year.1, third_DOB, Late Referral, Qtr, POE, DOB, County Name, County SES, Child Phase, Active, Service Coordinator, Parent Consent, Referral Source Type Name, Initial Eligibility, Initial Eligibility Date, Initial IFSP Date, Latest IFSP, Exit Reason, Exit Date, Year]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### Bullet 1
#     -What is the rate of re-referral?
#     -How many children have multiple referrals (by year or by Point of Entry Office (POE))?

# %%
reref = teis_merge2[teis_merge2.duplicated('Child ID')].sort_values('Child ID')
reref['Year'] = reref['Notification Date'].dt.year
reref.info()
#pulling out all instances when a child had a second, third, etc. referral
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18781 entries, 25 to 113753
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Child ID                   18781 non-null  int64
#  1   Notification Date          18781 non-null  datetime64[ns]
#  2   Fiscal Year                18535 non-null  object
#  3   Notification Month         18535 non-null  object
#  4   Tenn Region                18535 non-null  object
#  5   Fiscal Year.1              18535 non-null  float64
#  6   third_DOB                  18535 non-null  datetime64[ns]
#  7   Late Referral              384 non-null    float64
#  8   Qtr                        18535 non-null  float64
#  9   POE                        18781 non-null  object
#  10  DOB                        18781 non-null  datetime64[ns]
#  11  County Name                18780 non-null  object
#  12  County SES                 18780 non-null  object
#  13  Child Phase                18781 non-null  object
#  14  Active                     8223 non-null   object
#  15  Service Coordinator        18781 non-null  object
#  16  Parent Consent             9048 non-null   datetime64[ns]
#  17  Referral Source Type Name  18781 non-null  object
#  18  Initial Eligibility        8747 non-null   object
#  19  Initial Eligibility Date   8747 non-null   object
#  20  Initial IFSP Date          4464 non-null   object
#  21  Latest IFSP                4388 non-null   object
#  22  Exit Reason                13289 non-null  object
#  23  Exit Date                  7155 non-null   datetime64[ns]
#  24  Year                       18781 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(2), object(15)
# memory usage: 3.7+ MB

# %%
num_reref = len(np.unique(np.array(reref['Child ID'])))
num_reref
#number of children who had 2 or more referrals
# Out:
# 15641

# %%
refsou_reref = reref.groupby(['Referral Source Type Name'])['Child ID'].count()
refsou_reref = refsou_reref.to_frame().reset_index()
refsou_reref = refsou_reref.rename(columns = {'Child ID' : 'Total Re-referrals'})
refsou_reref
#Child ID count of re-referrals by Referral Source Type Name
# Out:
#         Referral Source Type Name  Total Re-referrals
# 0             Child Care provider                  52
# 1   Community/Child Find Activity                  43
# 2                             DCS                4211
# 3                             DHS                   2
# 4                 Dept. of Health                 675
# 5                            EIRA                  61
# 6     Early Head Start/Head Start                 167
# 7              Family and Friends                 100
# 8                   Foster Parent                 120
# 9                        Hospital                1169
# 10                            LEA                   2
# 11                            NHS                  52
# 12                           NICU                 559
# 13                             OT                  16
# 14                          Other                 466
# 15     Other Health Care Provider                 445
# 16                            PCP                6669
# 17                           PICU                   2
# 18                             PT                 108
# 19                         Parent                3767
# 20               Speech Therapist                  93
# 21                           TIPS                   2

# %%
refsou_ref = teis_merge2.groupby(['Referral Source Type Name'])['Child ID'].count()
refsou_ref = refsou_ref.to_frame().reset_index()
refsou_ref = refsou_ref.rename(columns = {'Child ID' : 'Total Referrals'})
refsou_ref
#Child ID count of re-referrals by Referral Source Type Name
# Out:
#         Referral Source Type Name  Total Referrals
# 0                           CAPTA                2
# 1             Child Care provider              430
# 2   Community/Child Find Activity              385
# 3                             DCS            25716
# 4                             DHS               12
# 5                            DMRS                1
# 6                 Dept. of Health             3683
# 7                            EIRA              352
# 8     Early Head Start/Head Start             1026
# 9              Family and Friends              524
# 10                  Foster Parent              425
# 11                       Hospital             7275
# 12                            LEA               16
# 13                            NHS              222
# 14                           NICU             3270
# 15                             OT               86
# 16                          Other             2606
# 17     Other Health Care Provider             2353
# 18                            PCP            43928
# 19                           PICU               25
# 20                             PT              618
# 21                         Parent            21920
# 22               Speech Therapist              646
# 23                           TIPS                3

# %%
refsou_rate = pd.merge(refsou_ref, refsou_reref, how='left').fillna(0)
refsou_rate['Re-referral Rate'] = (refsou_rate['Total Re-referrals'] / refsou_rate['Total Referrals'])*100
refsou_rate
# Out:
#         Referral Source Type Name  Total Referrals  Total Re-referrals  \
# 0                           CAPTA                2                 0.0
# 1             Child Care provider              430                52.0
# 2   Community/Child Find Activity              385                43.0
# 3                             DCS            25716              4211.0
# 4                             DHS               12                 2.0
# 5                            DMRS                1                 0.0
# 6                 Dept. of Health             3683               675.0
# 7                            EIRA              352                61.0
# 8     Early Head Start/Head Start             1026               167.0
# 9              Family and Friends              524               100.0
# 10                  Foster Parent              425               120.0
# 11                       Hospital             7275              1169.0
# 12                            LEA               16                 2.0
# 13                            NHS              222                52.0
# 14                           NICU             3270               559.0
# 15                             OT               86                16.0
# 16                          Other             2606               466.0
# 17     Other Health Care Provider             2353               445.0
# 18                            PCP            43928              6669.0
# 19                           PICU               25                 2.0
# 20                             PT              618               108.0
# 21                         Parent            21920              3767.0
# 22               Speech Therapist              646                93.0
# 23                           TIPS                3                 2.0
#
#     Re-referral Rate
# 0           0.000000
# 1          12.093023
# 2          11.168831
# 3          16.375019
# 4          16.666667
# 5           0.000000
# 6          18.327450
# 7          17.329545
# 8          16.276803
# 9          19.083969
# 10         28.235294
# 11         16.068729
# 12         12.500000
# 13         23.423423
# 14         17.094801
# 15         18.604651
# 16         17.881811
# 17         18.912027
# 18         15.181661
# 19          8.000000
# 20         17.475728
# 21         17.185219
# 22         14.396285
# 23         66.666667

# %%
poe_reref = reref.groupby(['POE'])['Child ID'].count()
poe_reref = poe_reref.to_frame().reset_index()
poe_reref = poe_reref.rename(columns = {'Child ID' : 'Total Re-referrals'})
poe_reref
#Child ID count of re-referrals by Point of Entry
# Out:
#   POE  Total Re-referrals
# 0  ET                3420
# 1  FT                1869
# 2  GN                3513
# 3  MD                3236
# 4  NW                1114
# 5  SC                2198
# 6  SE                1107
# 7  SW                 969
# 8  UC                1355

# %%
poe_ref = teis_merge2.groupby(['POE'])['Child ID'].count()
poe_ref = poe_ref.to_frame().reset_index()
poe_ref = poe_ref.rename(columns = {'Child ID' : 'Total Referrals'})
poe_ref
#Child ID count of re-referrals by Point of Entry
# Out:
#   POE  Total Referrals
# 0  ET            20583
# 1  FT            11335
# 2  GN            20239
# 3  MD            17642
# 4  NW             6592
# 5  SC            14967
# 6  SE             8790
# 7  SW             6142
# 8  UC             9234

# %%
poe_rate = pd.merge(poe_ref, poe_reref, how='left').fillna(0)
poe_rate['Re-referral Rate'] = (poe_rate['Total Re-referrals'] / poe_rate['Total Referrals'])*100
poe_rate
# Out:
#   POE  Total Referrals  Total Re-referrals  Re-referral Rate
# 0  ET            20583                3420         16.615654
# 1  FT            11335                1869         16.488752
# 2  GN            20239                3513         17.357577
# 3  MD            17642                3236         18.342592
# 4  NW             6592                1114         16.899272
# 5  SC            14967                2198         14.685642
# 6  SE             8790                1107         12.593857
# 7  SW             6142                 969         15.776620
# 8  UC             9234                1355         14.674031

# %%
yr_reref = reref.groupby(['Year'])['Child ID'].count()
yr_reref = yr_reref.to_frame().reset_index()
yr_reref = yr_reref.rename(columns = {'Child ID' : 'Total Re-referrals'})
yr_reref
#Child ID count of re-referrals by Year
# Out:
#    Year  Total Re-referrals
# 0  2016                1009
# 1  2017                2748
# 2  2018                3195
# 3  2019                3456
# 4  2020                3595
# 5  2021                3460
# 6  2022                1318

# %%
yr_ref = teis_merge2.groupby(['Year'])['Child ID'].count()
yr_ref = yr_ref.to_frame().reset_index()
yr_ref = yr_ref.rename(columns = {'Child ID' : 'Total Referrals'})
yr_ref
#Child ID count of re-referrals by Year
# Out:
#    Year  Total Referrals
# 0  2016             7904
# 1  2017            16936
# 2  2018            19119
# 3  2019            20307
# 4  2020            18975
# 5  2021            20878
# 6  2022            11405

# %%
yr_rate = pd.merge(yr_ref, yr_reref, how='left').fillna(0)
yr_rate['Re-referral Rate'] = (yr_rate['Total Re-referrals'] / yr_rate['Total Referrals'])*100
yr_rate
# Out:
#    Year  Total Referrals  Total Re-referrals  Re-referral Rate
# 0  2016             7904                1009         12.765688
# 1  2017            16936                2748         16.225791
# 2  2018            19119                3195         16.711125
# 3  2019            20307                3456         17.018762
# 4  2020            18975                3595         18.945982
# 5  2021            20878                3460         16.572469
# 6  2022            11405                1318         11.556335

# %%
poey_reref = reref.groupby(['POE', 'Year'])['Child ID'].count()
poey_reref = poey_reref.to_frame().reset_index()
poey_reref = poey_reref.rename(columns = {'Child ID' : 'Total Re-referrals'})
poey_reref
# Out:
#    POE  Year  Total Re-referrals
# 0   ET  2016                 204
# 1   ET  2017                 526
# 2   ET  2018                 617
# 3   ET  2019                 668
# 4   ET  2020                 620
# ..  ..   ...                 ...
# 58  UC  2018                 196
# 59  UC  2019                 214
# 60  UC  2020                 284
# 61  UC  2021                 328
# 62  UC  2022                 113
#
# [63 rows x 3 columns]

# %%
poey_ref = teis_merge2.groupby(['POE', 'Year'])['Child ID'].count()
poey_ref = poey_ref.to_frame().reset_index()
poey_ref = poey_ref.rename(columns = {'Child ID' : 'Total Referrals'})
poey_ref
# Out:
#    POE  Year  Total Referrals
# 0   ET  2016             1511
# 1   ET  2017             3252
# 2   ET  2018             3365
# 3   ET  2019             3681
# 4   ET  2020             3292
# ..  ..   ...              ...
# 58  UC  2018             1457
# 59  UC  2019             1486
# 60  UC  2020             1558
# 61  UC  2021             1825
# 62  UC  2022              960
#
# [63 rows x 3 columns]

# %%
poey_rate = pd.merge(poey_ref, poey_reref, how='left').fillna(0)
poey_rate['Re-referral Rate'] = (poey_rate['Total Re-referrals'] / poey_rate['Total Referrals'])*100
poey_rate
# Out:
#    POE  Year  Total Referrals  Total Re-referrals  Re-referral Rate
# 0   ET  2016             1511                 204         13.500993
# 1   ET  2017             3252                 526         16.174662
# 2   ET  2018             3365                 617         18.335810
# 3   ET  2019             3681                 668         18.147243
# 4   ET  2020             3292                 620         18.833536
# ..  ..   ...              ...                 ...               ...
# 58  UC  2018             1457                 196         13.452299
# 59  UC  2019             1486                 214         14.401077
# 60  UC  2020             1558                 284         18.228498
# 61  UC  2021             1825                 328         17.972603
# 62  UC  2022              960                 113         11.770833
#
# [63 rows x 5 columns]

# %%
ti = sns.FacetGrid(poey_rate, col="POE", col_wrap=3, hue="POE", palette = 'CMRmap_r')
ti.map_dataframe(sns.lineplot, x="Year", y="Re-referral Rate")
ti.set_axis_labels("Year", "Re-referral Rate");

# %% [markdown]
# #### POE List
#     - FT: First Tennessee
#     - UC: Upper Cumberland
#     - NW Northwest
#     - ET: East Tennessee
#     - GN: Greater Nashville
#     - SW: Southwest
#     - SE: Southeast
#     - SC: South Central
#     - MD: Memphis Delta

# %% [markdown]
# ### Bullet 2
# A referral is considered a "successful" referral if it results in an Individualized Family Service Plan (IFSP).
#
#     -Are there referral sources that have had higher rates of successful referrals?
#
# You can determine whether a referral was successful by looking at whether the Initial IFSP Date column is filled in or whether the Child Phase column is equal to IFSP.

# %%
ifsp = teis_merge2.loc[teis_merge2['Child Phase'] == 'IFSP']
ifsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45519 entries, 4 to 114363
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Child ID                   45519 non-null  int64
#  1   Notification Date          45519 non-null  datetime64[ns]
#  2   Fiscal Year                45361 non-null  object
#  3   Notification Month         45361 non-null  object
#  4   Tenn Region                45361 non-null  object
#  5   Fiscal Year.1              45361 non-null  float64
#  6   third_DOB                  45361 non-null  datetime64[ns]
#  7   Late Referral              585 non-null    float64
#  8   Qtr                        45361 non-null  float64
#  9   POE                        45519 non-null  object
#  10  DOB                        45519 non-null  datetime64[ns]
#  11  County Name                45519 non-null  object
#  12  County SES                 45519 non-null  object
#  13  Child Phase                45519 non-null  object
#  14  Active                     45493 non-null  object
#  15  Service Coordinator        45519 non-null  object
#  16  Parent Consent             45475 non-null  datetime64[ns]
#  17  Referral Source Type Name  45519 non-null  object
#  18  Initial Eligibility        45519 non-null  object
#  19  Initial Eligibility Date   45519 non-null  object
#  20  Initial IFSP Date          45519 non-null  object
#  21  Latest IFSP                44538 non-null  object
#  22  Exit Reason                36053 non-null  object
#  23  Exit Date                  36040 non-null  datetime64[ns]
#  24  Year                       45519 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(2), object(15)
# memory usage: 9.0+ MB

# %% [markdown]
# ### Bullet 3
# Some areas of potential concern are POEs having a:
#
#         -low proportion of referrals,
#         -a high average age of referrals,
#         -a low percent of total referrals resulting in an IFSP or
#         -a lower percent of eligible referrals resulting in an IFSP.
#
#     -How do POEs compare on these metrics, and
#     -which POEs are of concern on the basis of one or more of the listed criteria?

# %% [markdown]
# ### Bullet 4
# Look for patterns in referrals and re-referrals on the basis of the following:
#
#     - Age
#     - Referral source
#     - Socioeconomic status (County SES)

# %%
teis_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  datetime64[ns]
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third_DOB                  113256 non-null  datetime64[ns]
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        115524 non-null  object
#  10  DOB                        115524 non-null  datetime64[ns]
#  11  County Name                115520 non-null  object
#  12  County SES                 115520 non-null  object
#  13  Child Phase                115524 non-null  object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        115523 non-null  object
#  16  Parent Consent             75365 non-null   datetime64[ns]
#  17  Referral Source Type Name  115524 non-null  object
#  18  Initial Eligibility        71884 non-null   object
#  19  Initial Eligibility Date   71884 non-null   object
#  20  Initial IFSP Date          45520 non-null   object
#  21  Latest IFSP                44539 non-null   object
#  22  Exit Reason                96177 non-null   object
#  23  Exit Date                  85194 non-null   datetime64[ns]
#  24  Year                       115524 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(2), object(15)
# memory usage: 22.9+ MB

# %%
teis_q3 = teis_merge2[['DOB', 'Referral Source Type Name', 'County SES', 'POE', 'Notification Date', 'Initial IFSP Date']]
teis_q3
# Out:
#               DOB   Referral Source Type Name    County SES POE  \
# 0      2007-07-07                         DCS   Competitive  GN
# 1      2013-10-15                         PCP       At-Risk  UC
# 2      2013-11-13                      Parent  Transitional  NW
# 3      2013-10-01                      Parent       At-Risk  FT
# 4      2013-12-04             Dept. of Health  Transitional  UC
# ...           ...                         ...           ...  ..
# 115519 2020-05-20                         PCP  Transitional  GN
# 115520 2021-12-07                         PCP   Competitive  GN
# 115521 2022-06-21  Other Health Care Provider  Transitional  GN
# 115522 2022-06-17                    Hospital   Competitive  GN
# 115523 2019-12-26                         PCP   Competitive  SC
#
#        Notification Date Initial IFSP Date
# 0             2018-01-20               NaN
# 1             2016-08-17               NaN
# 2             2016-07-12               NaN
# 3             2016-09-14               NaN
# 4             2016-08-05        10/10/2016
# ...                  ...               ...
# 115519        2022-07-01               NaN
# 115520        2022-07-01               NaN
# 115521        2022-07-01               NaN
# 115522        2022-07-01               NaN
# 115523        2022-07-01               NaN
#
# [115524 rows x 6 columns]

# %%
teis_q3['DOB'] = pd.to_datetime(teis_q3['DOB'])
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/1089653640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teis_q3['DOB'] = pd.to_datetime(teis_q3['DOB'])

# %%
teis_q3.dtypes
# Out:
# DOB                          datetime64[ns]
# Referral Source Type Name            object
# County SES                           object
# POE                                  object
# Notification Date            datetime64[ns]
# Initial IFSP Date                    object
# dtype: object

# %%
teis_q3['Initial IFSP Date'] = pd.to_datetime(teis_q3['Initial IFSP Date'])
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/3527592537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teis_q3['Initial IFSP Date'] = pd.to_datetime(teis_q3['Initial IFSP Date'])

# %%
teis_q3["Notification age"] = teis_q3['Notification Date']- teis_q3['DOB']
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/1389747787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teis_q3["Notification age"] = teis_q3['Notification Date']- teis_q3['DOB']

# %%
teis_q3["ifsp_age"] = teis_q3['Initial IFSP Date']- teis_q3['DOB']
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/2916790454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teis_q3["ifsp_age"] = teis_q3['Initial IFSP Date']- teis_q3['DOB']

# %%
teis_q3
# Out:
#               DOB   Referral Source Type Name    County SES POE  \
# 0      2007-07-07                         DCS   Competitive  GN
# 1      2013-10-15                         PCP       At-Risk  UC
# 2      2013-11-13                      Parent  Transitional  NW
# 3      2013-10-01                      Parent       At-Risk  FT
# 4      2013-12-04             Dept. of Health  Transitional  UC
# ...           ...                         ...           ...  ..
# 115519 2020-05-20                         PCP  Transitional  GN
# 115520 2021-12-07                         PCP   Competitive  GN
# 115521 2022-06-21  Other Health Care Provider  Transitional  GN
# 115522 2022-06-17                    Hospital   Competitive  GN
# 115523 2019-12-26                         PCP   Competitive  SC
#
#        Notification Date Initial IFSP Date Notification age  ifsp_age
# 0             2018-01-20               NaT        3850 days       NaT
# 1             2016-08-17               NaT        1037 days       NaT
# 2             2016-07-12               NaT         972 days       NaT
# 3             2016-09-14               NaT        1079 days       NaT
# 4             2016-08-05        2016-10-10         975 days 1041 days
# ...                  ...               ...              ...       ...
# 115519        2022-07-01               NaT         772 days       NaT
# 115520        2022-07-01               NaT         206 days       NaT
# 115521        2022-07-01               NaT          10 days       NaT
# 115522        2022-07-01               NaT          14 days       NaT
# 115523        2022-07-01               NaT         918 days       NaT
#
# [115524 rows x 8 columns]

# %% [markdown]
# ### Bullet 5
# TEIS provides services to eligible infants and toddlers from birth to age 3.
#
#     -Are there any POE or service coordinators with high rates of early closure (a child exiting before reaching age 3)?
#     -For this question, only consider cases which have reached the IFSP phase.

# %%
ifsp_exit = ifsp.dropna(subset=['Exit Date'])
ifsp_exit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36040 entries, 4 to 113003
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Child ID                   36040 non-null  int64
#  1   Notification Date          36040 non-null  datetime64[ns]
#  2   Fiscal Year                35940 non-null  object
#  3   Notification Month         35940 non-null  object
#  4   Tenn Region                35940 non-null  object
#  5   Fiscal Year.1              35940 non-null  float64
#  6   third_DOB                  35940 non-null  datetime64[ns]
#  7   Late Referral              573 non-null    float64
#  8   Qtr                        35940 non-null  float64
#  9   POE                        36040 non-null  object
#  10  DOB                        36040 non-null  datetime64[ns]
#  11  County Name                36040 non-null  object
#  12  County SES                 36040 non-null  object
#  13  Child Phase                36040 non-null  object
#  14  Active                     36040 non-null  object
#  15  Service Coordinator        36040 non-null  object
#  16  Parent Consent             36007 non-null  datetime64[ns]
#  17  Referral Source Type Name  36040 non-null  object
#  18  Initial Eligibility        36040 non-null  object
#  19  Initial Eligibility Date   36040 non-null  object
#  20  Initial IFSP Date          36040 non-null  object
#  21  Latest IFSP                35082 non-null  object
#  22  Exit Reason                36040 non-null  object
#  23  Exit Date                  36040 non-null  datetime64[ns]
#  24  Year                       36040 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(2), object(15)
# memory usage: 7.1+ MB

# %%
ifsp_exit['Exit Age in m'] = (ifsp_exit['Exit Date']-ifsp_exit['DOB']).astype('timedelta64[M]')
ifsp_exit['Exit Age in m']
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/3034513916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ifsp_exit['Exit Age in m'] = (ifsp_exit['Exit Date']-ifsp_exit['DOB']).astype('timedelta64[M]')
# 4         35.0
# 8         32.0
# 15        35.0
# 16        35.0
# 18        35.0
#           ...
# 112126     6.0
# 112129    33.0
# 112174    25.0
# 112689     9.0
# 113003    20.0
# Name: Exit Age in m, Length: 36040, dtype: float64

# %%
ifsp_exit['Exit Age in d'] = ifsp_exit['Exit Date']-ifsp_exit['DOB']
ifsp_exit['Exit Age in d']
# Out:
# /var/folders/mv/bnk3r7_941d4rlgh9t2bsgvr0000gn/T/ipykernel_88972/2228021058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ifsp_exit['Exit Age in d'] = ifsp_exit['Exit Date']-ifsp_exit['DOB']
# 4        1095 days
# 8        1003 days
# 15       1095 days
# 16       1095 days
# 18       1095 days
#             ...
# 112126    200 days
# 112129   1022 days
# 112174    775 days
# 112689    278 days
# 113003    620 days
# Name: Exit Age in d, Length: 36040, dtype: timedelta64[ns]

# %%
POE_exits = ifsp_exit.groupby('POE')['Child ID'].count()
POE_exits
# Out:
# POE
# ET    5920
# FT    3749
# GN    5890
# MD    4848
# NW    1701
# SC    5544
# SE    2722
# SW    2050
# UC    3616
# Name: Child ID, dtype: int64

# %%
early_exits = ifsp_exit.loc[ifsp_exit['Exit Age in m'] < 35.0]
early_exits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14737 entries, 8 to 113003
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Child ID                   14737 non-null  int64
#  1   Notification Date          14737 non-null  datetime64[ns]
#  2   Fiscal Year                14701 non-null  object
#  3   Notification Month         14701 non-null  object
#  4   Tenn Region                14701 non-null  object
#  5   Fiscal Year.1              14701 non-null  float64
#  6   third_DOB                  14701 non-null  datetime64[ns]
#  7   Late Referral              10 non-null     float64
#  8   Qtr                        14701 non-null  float64
#  9   POE                        14737 non-null  object
#  10  DOB                        14737 non-null  datetime64[ns]
#  11  County Name                14737 non-null  object
#  12  County SES                 14737 non-null  object
#  13  Child Phase                14737 non-null  object
#  14  Active                     14737 non-null  object
#  15  Service Coordinator        14737 non-null  object
#  16  Parent Consent             14708 non-null  datetime64[ns]
#  17  Referral Source Type Name  14737 non-null  object
#  18  Initial Eligibility        14737 non-null  object
#  19  Initial Eligibility Date   14737 non-null  object
#  20  Initial IFSP Date          14737 non-null  object
#  21  Latest IFSP                13979 non-null  object
#  22  Exit Reason                14737 non-null  object
#  23  Exit Date                  14737 non-null  datetime64[ns]
#  24  Year                       14737 non-null  int64
#  25  Exit Age in m              14737 non-null  float64
#  26  Exit Age in d              14737 non-null  timedelta64[ns]
# dtypes: datetime64[ns](5), float64(4), int64(2), object(15), timedelta64[ns](1)
# memory usage: 3.1+ MB

# %%
early_exits['Exit Age in m'].value_counts()
# Out:
# 34.0    872
# 32.0    800
# 31.0    784
# 33.0    729
# 25.0    690
# 29.0    685
# 28.0    678
# 30.0    677
# 27.0    671
# 26.0    603
# 22.0    556
# 24.0    536
# 23.0    532
# 21.0    491
# 20.0    444
# 19.0    423
# 18.0    409
# 14.0    377
# 13.0    367
# 15.0    347
# 17.0    347
# 12.0    323
# 16.0    311
# 11.0    294
# 9.0     283
# 8.0     264
# 10.0    246
# 7.0     233
# 6.0     211
# 5.0     194
# 4.0     153
# 3.0     118
# 2.0      63
# 1.0      25
# 0.0       1
# Name: Exit Age in m, dtype: int64

# %%
POE_early_exits = early_exits.groupby('POE')['Child ID'].count()
POE_early_exits
# Out:
# POE
# ET    2565
# FT    1577
# GN    2190
# MD    1935
# NW     822
# SC    1999
# SE    1109
# SW    1086
# UC    1454
# Name: Child ID, dtype: int64

# %%
POE_early_exit_rate = (POE_early_exits/POE_exits)*100
POE_early_exit_rate
# Out:
# POE
# ET    43.327703
# FT    42.064551
# GN    37.181664
# MD    39.913366
# NW    48.324515
# SC    36.056999
# SE    40.742101
# SW    52.975610
# UC    40.210177
# Name: Child ID, dtype: float64
