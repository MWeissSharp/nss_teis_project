# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
teis_p = pd.read_csv('../data/teis_p.csv')

# %%
teis_p = teis_p.rename(columns = {'County SES ': 'County SES', 'Notification Date' : 'Notified On'})

# %%
teis_c = pd.read_csv('../data/teis_c.csv')

# %%
teis_c = teis_c.rename(columns = {'Notification/ Referral Date':'Notified On'})

# %%
teis_p
# Out:
#       POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0      ET    411812  12/14/2016      Blount  Transitional  Notification
# 1      ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2      ET    419400    3/4/2016       Roane  Transitional  Notification
# 3      ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4      ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...    ..       ...         ...         ...           ...           ...
# 96575  UC    519094   4/10/2020       Macon  Transitional   Eligibility
# 96576  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 96577  UC    525460   8/27/2019      Sumner   Competitive  Notification
# 96578  UC    528535    2/8/2022       Smith  Transitional    Evaluation
# 96579  UC    514216    2/4/2021      Sumner   Competitive          IFSP
#
#       Active Service Coordinator Notified On Parent Consent Date  \
# ...

# %%
#df = pd.read_csv('data.csv')

#print(df.to_string())

# %%
teis_c
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notified On Parent Consent Date  \
# ...

# %%
unique_monthly = teis_c['Child ID'].nunique()
unique_monthly
# Out:
# 94950

# %%
teis_c ['Child ID'].value_counts()
# Out:
# 471335    7
# 452977    7
# 447124    7
# 480297    7
# 407230    6
#          ..
# 448406    1
# 447195    1
# 446310    1
# 446750    1
# 528535    1
# Name: Child ID, Length: 94950, dtype: int64

# %%
rerefs = teis_c ['Child ID'].value_counts() > 1
rerefs_total = rerefs.sum()

# %%
rerefs
# Out:
# 471335     True
# 452977     True
# 447124     True
# 480297     True
# 407230     True
#           ...
# 448406    False
# 447195    False
# 446310    False
# 446750    False
# 528535    False
# Name: Child ID, Length: 94950, dtype: bool

# %%
rerefs_total/unique_monthly
# Out:
# 0.16078988941548183

# %%
#df['your_column'].value_counts()

# %%
#concat_data = pd.concat([df_2018, df_2019])
#concat_data

# %%
#concat_data = concat_data.reset_index(drop = True)

# %%
concat_data = pd.concat([teis_p, teis_c])
concat_data
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 113251  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534   3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535    2/8/2022       Smith  Transitional    Evaluation
#
#        Active Service Coordinator Notified On Parent Consent Date  ...  \
# ...

# %%
concat_data = concat_data.reset_index(drop = True)

# %%
concat_data
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 209831  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 209832  UC    528534   3/13/2022      Sumner   Competitive          IFSP
# 209833  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
# 209834  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 209835  UC    528535    2/8/2022       Smith  Transitional    Evaluation
#
#        Active Service Coordinator Notified On Parent Consent Date  ...  \
# ...

# %%
#notification date update

# %%
#dates are strings

# %%
teis_clean = concat_data.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Child Count', 'Referral Source Category'])

# %%
teis_clean
# Out:
#        POE  Child ID         DOB County Name    County SES   Child Phase  \
# 0       ET    411812  12/14/2016      Blount  Transitional  Notification
# 1       ET    417398    4/6/2015        Knox  Transitional   Eligibility
# 2       ET    419400    3/4/2016       Roane  Transitional  Notification
# 3       ET    397571   5/11/2015        Knox  Transitional   Eligibility
# 4       ET    404648   9/23/2015        Knox  Transitional          IFSP
# ...     ..       ...         ...         ...           ...           ...
# 209831  UC    528759    4/7/2021      Sumner   Competitive    Evaluation
# 209832  UC    528534   3/13/2022      Sumner   Competitive          IFSP
# 209833  UC    528430    1/5/2022  Cumberland  Transitional   Eligibility
# 209834  UC    528253   9/12/2020      Sumner   Competitive          IFSP
# 209835  UC    528535    2/8/2022       Smith  Transitional    Evaluation
#
#        Active Service Coordinator Notified On Parent Consent Date  ...  \
# ...

# %%
unique_child_id = teis_clean['Child ID'].nunique()
unique_child_id
# Out:
# 96743

# %%
teis_clean.tail(5)
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 209831  UC    528759   4/7/2021      Sumner   Competitive   Evaluation      A
# 209832  UC    528534  3/13/2022      Sumner   Competitive         IFSP      A
# 209833  UC    528430   1/5/2022  Cumberland  Transitional  Eligibility      A
# 209834  UC    528253  9/12/2020      Sumner   Competitive         IFSP      A
# 209835  UC    528535   2/8/2022       Smith  Transitional   Evaluation      A
#
#        Service Coordinator Notified On Parent Consent Date  ... Tenn Region  \
# 209831   Sherry Roberts-DS   5/16/2022           5/26/2022  ...      Middle
# 209832         Robyn Hogan   5/11/2022           5/23/2022  ...      Middle
# 209833          Lisa Davis   5/10/2022           5/18/2022  ...      Middle
# 209834          Taylor Lee    5/6/2022           5/11/2022  ...      Middle
# 209835   Sherry Roberts-DS   5/11/2022           5/27/2022  ...      Middle
#
# ...

# %%
percent_of_unique_id = 96743/209836
percent_of_unique_id
# Out:
# 0.46104100345031357

# %%
unique_child_id
# Out:
# 96743

# %%
teis_clean.value_counts('POE')
# Out:
# POE
# ET    37349
# GN    36586
# MD    31626
# SC    27321
# FT    20593
# UC    16918
# SE    16230
# NW    11974
# SW    11239
# dtype: int64

# %%
teis_clean.value_counts('Child ID')
# Out:
# Child ID
# 471335    8
# 480297    8
# 447124    8
# 452977    8
# 404052    7
#          ..
# 530083    1
# 530082    1
# 530081    1
# 530080    1
# 531596    1
# Length: 96743, dtype: int64

# %%
teis_clean.value_counts('DOB')
# Out:
# DOB
# 7/21/2016     176
# 12/12/2018    163
# 12/19/2018    160
# 8/8/2019      160
# 7/2/2019      159
#              ...
# 6/19/2022       1
# 5/19/2022       1
# 6/15/2022       1
# 6/27/2022       1
# 6/29/2022       1
# Length: 3202, dtype: int64

# %%
teis_clean.value_counts('County Name')
# Out:
# County Name
# Shelby        31612
# Davidson      20448
# Knox          15859
# Rutherford    10522
# Hamilton       8423
#               ...
# Perry           195
# Clay            179
# Van Buren       169
# Pickett          98
# Moore            93
# Length: 95, dtype: int64

# %%
teis_clean.value_counts('County SES')
# Out:
# County SES
# Transitional    134226
# Competitive      41424
# At-Risk          24493
# Attainment        4956
# Distressed        4728
# dtype: int64

# %%
teis_clean.value_counts('County SES')
# Out:
# County SES
# Transitional    134226
# Competitive      41424
# At-Risk          24493
# Attainment        4956
# Distressed        4728
# dtype: int64

# %%
teis_c
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notified On Parent Consent Date  \
# ...

# %%
unique_monthly = teis_c['Child ID'].nunique()
unique_monthly

teis_c ['Child ID'].value_counts()
# Out:
# 471335    7
# 452977    7
# 447124    7
# 480297    7
# 407230    6
#          ..
# 448406    1
# 447195    1
# 446310    1
# 446750    1
# 528535    1
# Name: Child ID, Length: 94950, dtype: int64

# %%
# Variable_name = dataframe_name [ row(s) , column(s) ]
pd.set_option('display.max_columns', None)

# %%
drop child phase
# Out:
#   Input In [64]
#     drop child phase
#          ^
# SyntaxError: invalid syntax

# %%
poe dob county name ses drop child active follwo up service coordinator

# %%
teis_merge = pd.merge(teis_c, teis_p, how='outer', on=['Child ID', 'Notified On'])
teis_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE_x                        113256 non-null  object
#  1   Child ID                     115524 non-null  int64
#  2   DOB_x                        113256 non-null  object
#  3   County Name_x                113251 non-null  object
#  4   County SES_x                 113251 non-null  object
#  5   Child Phase_x                113256 non-null  object
#  6   Active_x                     113256 non-null  object
#  7   Service Coordinator_x        113255 non-null  object
#  8   Notified On                  115524 non-null  object
#  9   Parent Consent Date_x        58101 non-null   object
#  10  Referral Source Type Name_x  113256 non-null  object
#  11  Initial Eligibility_x        40762 non-null   object
# ...

# %%
teis_c

# %% [markdown]
# poe dob county name ses drop child active follwo up service coordinator

# %%
teis_c_revised = teis_c.drop('POE', 'County Name' axis=1)
teis_c_revised
# Out:
#         Child ID        DOB County Name    County SES   Child Phase Active  \
# 0         403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1         404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2         403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3         404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4         404154  4/18/2015     Hawkins       At-Risk          IFSP      A
# ...          ...        ...         ...           ...           ...    ...
# 113251    528759   4/7/2021      Sumner   Competitive    Evaluation      A
# 113252    528534  3/13/2022      Sumner   Competitive          IFSP      A
# 113253    528430   1/5/2022  Cumberland  Transitional   Eligibility      A
# 113254    528253  9/12/2020      Sumner   Competitive          IFSP      A
# 113255    528535   2/8/2022       Smith  Transitional    Evaluation      A
#
# ...

# %%
print(teis_c.columns.values)
# Out:
# ['POE' 'Child ID' 'DOB' 'County Name' 'County SES' 'Child Phase' 'Active'
#  'Service Coordinator' 'Notified On' 'Parent Consent Date'
#  'Referral Source Type Name' 'Initial Eligibility'
#  'Initial Eligibility Date' 'Initial IFSP Date' 'Latest IFSP Date'
#  'Exit Reason' 'Exit Date' 'Fiscal Year' 'Notification Month'
#  'Tenn Region' 'Referral Count' 'Evaluation Count' 'Eligibility Count'
#  'IFSP Count' 'Service Coordinator Counter' 'Fiscal Year.1' 'Child Count'
#  '2012 Child Count' '2013 Child Count' 'third DOB' 'Late Referral' 'Qtr'
#  ' QTR ' 'Referral Source Category']

# %%
teis_c2 = teis_c.drop(columns = ['Child Phase','POE','County Name', 'County SES' , 'Active', 'Service Coordinator', 'Parent Consent Date', 'Initial IFSP Date',
                                 'Latest IFSP Date', 'Exit Reason', 'Exit Date','2012 Child Count', '2013 Child Count', 
                                 'Service Coordinator Counter', 'Referral Count', 'Evaluation Count', 'Eligibility Count', 
                                 'IFSP Count', 'Child Count', ' QTR ', 'Referral Source Category', 'Initial Eligibility','Initial Eligibility Date'])
teis_c2
# Out:
#         Child ID        DOB Notified On Referral Source Type Name Fiscal Year  \
# 0         403339   8/9/2014    7/1/2016             Foster Parent   2016-2017
# 1         404085  7/31/2013    7/1/2016                       DCS   2016-2017
# 2         403623   2/5/2016    7/1/2016                       DCS   2016-2017
# 3         404157  12/6/2015    7/1/2016                       PCP   2016-2017
# 4         404154  4/18/2015    7/1/2016                    Parent   2016-2017
# ...          ...        ...         ...                       ...         ...
# 113251    528759   4/7/2021   5/16/2022                    Parent   2021-2022
# 113252    528534  3/13/2022   5/11/2022                  Hospital   2021-2022
# 113253    528430   1/5/2022   5/10/2022                    Parent   2021-2022
# 113254    528253  9/12/2020    5/6/2022                       PCP   2021-2022
# 113255    528535   2/8/2022   5/11/2022                    Parent   2021-2022
#
# ...

# %%
teis_merge2 = pd.merge(teis_c2, teis_p, how ='outer')
teis_merge2
# Out:
#         Child ID         DOB Notified On   Referral Source Type Name  \
# 0         403339    8/9/2014    7/1/2016               Foster Parent
# 1         404085   7/31/2013    7/1/2016                         DCS
# 2         403623    2/5/2016    7/1/2016                         DCS
# 3         404157   12/6/2015    7/1/2016                         PCP
# 4         404154   4/18/2015    7/1/2016                      Parent
# ...          ...         ...         ...                         ...
# 116210    530351   5/21/2020   6/13/2022  Other Health Care Provider
# 116211    531302   10/8/2020   6/28/2022                        EIRA
# 116212    530326    3/9/2022   6/10/2022                    Hospital
# 116213    530221   5/20/2021    6/9/2022  Other Health Care Provider
# 116214    495655  12/11/2020   6/17/2022                         PCP
#
#        Fiscal Year Notification Month Tenn Region  Fiscal Year.1  third DOB  \
# ...

# %%
print(teis_merge2.columns.values)
# Out:
# ['Child ID' 'DOB' 'Notified On' 'Referral Source Type Name' 'Fiscal Year'
#  'Notification Month' 'Tenn Region' 'Fiscal Year.1' 'third DOB'
#  'Late Referral' 'Qtr' 'POE' 'County Name' 'County SES' 'Child Phase'
#  'Active' 'Service Coordinator' 'Parent Consent Date'
#  'Initial Eligibility' 'Initial Eligibility Date' 'Initial IFSP Date'
#  'Latest IFSP Date' 'Exit Reason' 'Exit Date']

# %%
all_dups2 = teis_merge2[teis_merge2.duplicated(['Child ID', 'Notified On'], keep=False)].sort_values('Child ID')
all_dups2[['Child ID', 'DOB', 'Notified On', 'Referral Source Type Name']].head(40)
# Out:
#         Child ID         DOB Notified On      Referral Source Type Name
# 9104      382242  11/17/2014   1/27/2017                Dept. of Health
# 113284    382242  11/17/2014   1/27/2017                            PCP
# 10585     384883   1/10/2015   2/28/2017                         Parent
# 113323    384883   1/10/2015   2/28/2017             Family and Friends
# 5700      385713    3/3/2014   11/3/2016                            PCP
# 113327    385713    3/4/2014   11/3/2016                            PCP
# 113274    389667   12/3/2014   5/12/2017                         Parent
# 14170     389667  12/30/2014   5/12/2017                         Parent
# 1446      391807   5/27/2015    8/4/2016                          Other
# 113278    391807   5/27/2015    8/4/2016                            DCS
# 10355     397573    9/1/2015   2/23/2017                            DCS
# 113319    397573   9/30/2015   2/23/2017                            DCS
# ...

# %%
all_dups2[~all_dups2.duplicated(subset=['Child ID', 'Notified On','Referral Source Type Name'], keep=False)]
# Out:
#         Child ID         DOB Notified On Referral Source Type Name  \
# 9104      382242  11/17/2014   1/27/2017           Dept. of Health
# 113284    382242  11/17/2014   1/27/2017                       PCP
# 10585     384883   1/10/2015   2/28/2017                    Parent
# 113323    384883   1/10/2015   2/28/2017        Family and Friends
# 1446      391807   5/27/2015    8/4/2016                     Other
# ...          ...         ...         ...                       ...
# 115897    522841    9/8/2019   2/22/2022                  Hospital
# 105679    523067   3/19/2020   2/25/2022                    Parent
# 114142    523067   3/19/2020   2/25/2022             Foster Parent
# 105678    523068   3/22/2021   2/25/2022                    Parent
# 114141    523068   3/22/2021   2/25/2022             Foster Parent
#
#        Fiscal Year Notification Month Tenn Region  Fiscal Year.1   third DOB  \
# 9104     2016-2017                Jan     Eastern         2016.0  11/17/2017
# ...

# %%
reref = teis_merge2[teis_merge2.duplicated(['Child ID'], keep=False)].sort_values('Child ID') 
reref
# Out:
#         Child ID         DOB Notified On Referral Source Type Name  \
# 6007      360966   1/18/2014  11/10/2016                  Hospital
# 8326      360966   1/18/2014   1/12/2017                       DCS
# 5441      361021   2/17/2014  10/28/2016                     Other
# 6658      361021   2/17/2014  11/29/2016        Family and Friends
# 5189      361038  12/25/2013  10/24/2016                       DCS
# ...          ...         ...         ...                       ...
# 113031    529473    7/4/2020   5/27/2022                       DCS
# 111693    529524   11/2/2020   5/31/2022                       PCP
# 114343    529524   11/2/2020   6/21/2022                       PCP
# 114597    529571    2/1/2022   5/31/2022                      NICU
# 111885    529571    2/2/2022   5/31/2022                      NICU
#
#        Fiscal Year Notification Month Tenn Region  Fiscal Year.1   third DOB  \
# 6007     2016-2017                Nov     Eastern         2016.0   1/18/2017
# ...
